# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
Prepare consolidated data

"""

# Import libraries

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import pandas as pd
import aerospike
import json

print(__doc__)

class Consolidate:
    
    def __init__(self):
        pass
        
    def read(self, file):
        data = pd.read_excel(file)
        return data

    def clean_data(self, data):
    
        # Select numeric data alone from data object
        numeric_data = data.loc[:, data.dtypes != object]
    
        # Select string data alone from data object to trim
        trim_data = data.select_dtypes(['object'])
    
        # Trim all string objects
        trim_data = trim_data.apply(lambda x: x.str.strip())
    
        # Merge numeric and string data in to data object
        data = pd.concat([numeric_data, trim_data], axis=1)
    
        # Change column name to lower case
        data.columns = [x.lower() for x in data.columns]
        return data
    
    def load_data(self, data):
            
        # Split dataframe into key and records
        key = data['vehicle_no']
    
        record_json = data.to_dict(orient='records')
    
        config = {
            'hosts': [ ('127.0.0.1', 3000) ]
        }

        # Create a client and connect it to the cluster
        try:
            client = aerospike.client(config).connect()
        except:
            import sys
            print("failed to connect to the cluster with", config['hosts'])
            sys.exit(1)
    
        # Records are addressable via a tuple of (namespace, set, key)
        for pk, bin in zip(key, record_json):
            string = "('dev', 'customer_data', "
            string +=`pk`
            string = string + ")"
        
            from ast import literal_eval as make_tuple
            string = make_tuple(string)
        
            try:
                client = aerospike.client(config).connect()
                # Write a record
                client.put(string, bin)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)

            # Read a record after insert for verification
            (key, metadata, record) = client.get(string)
            print (key, record)
        
            # Close the connection to the Aerospike cluster
            client.close()
    
    def remove_data(self, data):

        key = data['vehicle_no']
    
        config = {
          'hosts': [ ('127.0.0.1', 3000) ]
        }

        # Create a client and connect it to the cluster
        try:
            client = aerospike.client(config).connect()
        except:
            import sys
            print("failed to connect to the cluster with", config['hosts'])
            sys.exit(1)
    
        # Records are addressable via a tuple of (namespace, set, key)
        for pk in key:
            string = "('dev', 'customer_data', "
            string +=`pk`
            string = string + ")"
        
            from ast import literal_eval as make_tuple
            string = make_tuple(string)
        
            try:
                client = aerospike.client(config).connect()
                # Remove a record
                client.remove(string)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)

            # Close the connection to the Aerospike cluster
            client.close()
    
def drive(mode):
    
    cons = Consolidate()

    # Read customer details excel
    data1 = cons.read("/home/azureuser/Aerospike/data/customer/customer details.xls")
    
    # Clean data1
    data1 = cons.clean_data(data1)
    #print (data1.columns)
    
    # Read Customer vehicle excel
    data2 = cons.read("/home/azureuser/Aerospike/data/customer/Customer_vehicle.xls")
    
    # Clean data2
    data2 = cons.clean_data(data2)
    #print (data2.columns)
    
    # Merge data1 and data2 by cust_id
    data2 = pd.merge(data1, data2, on='cust_id', how='inner')
    
    # Read Motor vehicle report excel
    data3 = cons.read("/home/azureuser/Aerospike/data/customer/Motor_vehicle_report.xls")
    data3 = data3.drop('Gender',1)
    # Clean data3
    data3 = cons.clean_data(data3)
    
    # Merge data2 and data3 by vehicle_no
    data3 = pd.merge(data2, data3, on='vehicle_no', how='inner')
    #print (data3.columns)
    
    # Read Customer address excel
    data4 = cons.read("/home/azureuser/Aerospike/data/customer/customer_address.xls")
    
    # Clean data4
    data4 = cons.clean_data(data4)
    
    # Merge data3 and data4 by cust_id
    data4 = pd.merge(data3, data4, on='cust_id', how='inner')
    #print (data4.columns)
    data4 = data4.drop('dob',1)
    #print (data4.columns)
    #print (data4.count)
    
    if mode == 'load':
        # Load data in to aerospike
        cons.load_data(data4)
    else:
        # Remove data from aerospike
        cons.remove_data(data4)
    
if __name__ == '__main__':
    drive('load')
# Out:
# Prepare consolidated data
#
#
# ('dev', 'customer_data', None, bytearray(b'\xa5&\x82\x10q\x8d\xb1\xac\xd4\xed\x08y\xdc\x1d\xb0\xcb\xef\x06?\x9d')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LOWE', 'weight': 61, 'email_id': 'Quatasia@yahoo.com', 'vin': 'SHSRD78494U256469', 'pincode': 52531, 'height': 6.8, 'child1_name': 'Lillian', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Chicago', 'first_name': 'Quatasia', 'credit_rating': 571, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-01 00:00:00'), 'state': 'Illinois', 'date_of_birth': Timestamp('1982-10-21 00:00:00'), 'ssn_no': '65-65-3156', 'model_id': 'M00039', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1984-10-21 00:00:00'), 'cust_id': 2396305636, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CTO', 'class_id': 'CCLA', 'gender': 'F', 'age': 34, 'vehicle_no': 76990, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '715 Calhoun Street'}
# ('dev', 'customer_data', None, bytearray(b'\xa9\x8d\xd0!\xea.\xf9\xb7"|)\x97\xa8 \xfc7t\\\xb2\x10')) {'child2_d_o_b': nan, 'spouse_name': 'Abril', 'last_name': 'CROSS', 'weight': 50, 'email_id': 'Elia@yahoo.com', 'vin': '2C3CA5CG5BH552838', 'pincode': 50001, 'height': 4.8, 'child1_name': 'Sarah', 'no_of_violatn': 0, 'no_of_child': 1, 'city': nan, 'first_name': 'Elia', 'credit_rating': 502, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-10 00:00:00'), 'state': 'Bluffington', 'date_of_birth': Timestamp('1988-02-07 00:00:00'), 'ssn_no': '95-95-1076', 'model_id': 'M00012', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1986-02-07 00:00:00'), 'cust_id': 84711641, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2005-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'M', 'age': 29, 'vehicle_no': 67623, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '21 Jumbo Street'}
# ('dev', 'customer_data', None, bytearray(b'I\x0bW\x95\xa7V(v\xb70P.uh\xd4\xc9v\xa0Lt')) {'child2_d_o_b': nan, 'spouse_name': 'Yamileth', 'last_name': 'MONTES', 'weight': 57, 'email_id': 'Mardy@yahoo.com', 'vin': '1G1NE52J53M570317', 'pincode': 50002, 'height': 5.8, 'child1_name': 'May', 'no_of_violatn': 3, 'no_of_child': 1, 'city': 'Hollywood', 'first_name': 'Mardy', 'credit_rating': 546, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-26 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1994-02-22 00:00:00'), 'ssn_no': '15-15-2405', 'model_id': 'M00071', 'license_susp': 'No', 'job_type': 'Government', 'spouse_d_o_b': Timestamp('1992-02-22 00:00:00'), 'cust_id': 1561684799, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'Doctor', 'class_id': 'CGLS', 'gender': 'M', 'age': 23, 'vehicle_no': 60734, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'lM\xedy04\x01\xedX>\xfe \xd5@\x8c\xd1\xcc2\xec\x02')) {'child2_d_o_b': nan, 'spouse_name': 'Stevie', 'last_name': 'TODD', 'weight': 95, 'email_id': 'Elisandro@yahoo.com', 'vin': 'G720VHP33368', 'pincode': 50003, 'height': 6.3, 'child1_name': 'Edith', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Santa Monica', 'first_name': 'Elisandro', 'credit_rating': 770, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-01-28 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1987-05-07 00:00:00'), 'ssn_no': '36-36-9105', 'model_id': 'M00034', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1985-05-07 00:00:00'), 'cust_id': 9006719754, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Cardiologist', 'class_id': 'CS', 'gender': 'M', 'age': 29, 'vehicle_no': 65609, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '834 Ocean Vista Avenue #201'}
# ('dev', 'customer_data', None, bytearray(b'5s9P\x16\xbc\xa3\xeb\xfcA\x16\x87k\xd8\xad]\xf9\x0b\x1aY')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'PARSONS', 'weight': 69, 'email_id': 'Lyndell@yahoo.com', 'vin': '3FAHP07Z87R279717', 'pincode': 50830, 'height': 4.6, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'New York', 'first_name': 'Lyndell', 'credit_rating': 618, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1970-05-20 00:00:00'), 'ssn_no': nan, 'model_id': 'M00045', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1972-05-20 00:00:00'), 'cust_id': 3947774146, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'Anesthesiologist', 'class_id': 'CCLS', 'gender': 'F', 'age': 46, 'vehicle_no': 74809, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '25 West 68th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xcdN\xad\xb9J\xb6}T\xb2L>\\\xe0-\xfb\xbe\xc9\xed\x8e\x90')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LUCAS', 'weight': 60, 'email_id': 'Retta@yahoo.com', 'vin': 'STR96955J607', 'pincode': 52530, 'height': 4.6, 'child1_name': 'Gertrude', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Los Angeles', 'first_name': 'Retta', 'credit_rating': 560, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-01-25 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1963-12-05 00:00:00'), 'ssn_no': '44-44-2805', 'model_id': 'M00031', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1965-12-05 00:00:00'), 'cust_id': 2006085121, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CFO', 'class_id': 'CS', 'gender': 'F', 'age': 53, 'vehicle_no': 59888, 'child2_name': 'Gertrude', 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '4222 Clinton Way'}
# ('dev', 'customer_data', None, bytearray(b'\x88\x12\x08@\xb1\xb4\xdc\xbf\x86M\x88l\xc0wS \x13\x9b\x84K')) {'child2_d_o_b': nan, 'spouse_name': 'Hayden', 'last_name': 'CHOI', 'weight': 59, 'email_id': 'Lue@yahoo.com', 'vin': 'WBA3B5G57FNS17981', 'pincode': 52201, 'height': 5.0, 'child1_name': 'Mamie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Manhattan', 'first_name': 'Lue', 'credit_rating': 557, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-02-27 00:00:00'), 'state': 'New York City', 'date_of_birth': Timestamp('1954-04-26 00:00:00'), 'ssn_no': '61-61-2716', 'model_id': 'M00072', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1952-04-26 00:00:00'), 'cust_id': 1907459679, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Professor', 'class_id': 'CG', 'gender': 'M', 'age': 62, 'vehicle_no': 83651, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '890 Fifth Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\x90Q]>J\x84\xe03\x1f\xc5\xc2}\xfe\x95W\xa74K\xbd\xf3')) {'child2_d_o_b': nan, 'spouse_name': 'Serenity', 'last_name': 'SPENCE', 'weight': 61, 'email_id': 'Nolan@gmail.com', 'vin': 'JN1CA21A5WM805526', 'pincode': 51001, 'height': 6.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Metropolis', 'first_name': 'Nolan', 'credit_rating': 571, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1995-02-11 00:00:00'), 'ssn_no': '24-24-3158', 'model_id': 'M00055', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1993-02-11 00:00:00'), 'cust_id': 2398850356, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Chief Architect', 'class_id': 'CGLE', 'gender': 'M', 'age': 22, 'vehicle_no': 86773, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '344 Clinton St., Apt. 3B'}
# ('dev', 'customer_data', None, bytearray(b'\x16\x06\xdcp(\x1ai\x001\xde7]\x8b\xfew\x99\xbcV\x8f\xaf')) {'child2_d_o_b': nan, 'spouse_name': 'Presley', 'last_name': 'SPEARS', 'weight': 92, 'email_id': 'Erasmo@gmail.com', 'vin': '1F66F5DY8F0A02001', 'pincode': 50510, 'height': 4.2, 'child1_name': 'Rose', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Erasmo', 'credit_rating': 754, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2021-10-06 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1992-10-06 00:00:00'), 'ssn_no': '87-87-8637', 'model_id': 'M00030', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1990-10-06 00:00:00'), 'cust_id': 8486613847, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CS', 'gender': 'M', 'age': 24, 'vehicle_no': 89200, 'child2_name': 'Rose', 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '1049 Park Avenue'}
# ('dev', 'customer_data', None, bytearray(b'PA9K\x9e\xe6\x05\x9dQ~\x8b\xbb\xa7\xf9O(\xb8\xb7\x9cW')) {'child2_d_o_b': nan, 'spouse_name': 'Anastasia', 'last_name': 'HANSON', 'weight': 70, 'email_id': 'Leslie@gmail.com', 'vin': '4S3BMBG69A3244703', 'pincode': 52531, 'height': 5.2, 'child1_name': 'Harriet', 'no_of_violatn': 6, 'no_of_child': 2, 'city': 'Chicago', 'first_name': 'Leslie', 'credit_rating': 625, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-03-14 00:00:00'), 'state': 'Illinois', 'date_of_birth': Timestamp('1953-08-05 00:00:00'), 'ssn_no': '69-69-4775', 'model_id': 'M00091', 'license_susp': 'Yes', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1951-08-05 00:00:00'), 'cust_id': 4195354888, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CE', 'gender': 'M', 'age': 63, 'vehicle_no': 83280, 'child2_name': 'Harriet', 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '711 Calhoun Street'}
# ('dev', 'customer_data', None, bytearray(b'\xa5v\xab\xc3d\x89\xbf#\xd3\x04\xfeB\x0108;\x8cw`1')) {'child2_d_o_b': nan, 'spouse_name': 'Giuliana', 'last_name': 'OLSON', 'weight': 94, 'email_id': 'Flor@gmail.com', 'vin': 'JN8AF5MV7DT223764', 'pincode': 50005, 'height': 5.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Hollywood', 'first_name': 'Flor', 'credit_rating': 765, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1990-12-16 00:00:00'), 'ssn_no': nan, 'model_id': 'M00013', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1988-12-16 00:00:00'), 'cust_id': 8833668145, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CC', 'gender': 'M', 'age': 26, 'vehicle_no': 75573, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'\xedA\x97f\x8c\x14\x02\x9bM\xa4\r\xca\xcf\xcbV\xb7!4\xa3\x04')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'SIMS', 'weight': 60, 'email_id': 'Paulla@gmail.com', 'vin': '1FAFP56S11A258380', 'pincode': 52202, 'height': 6.3, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Camden', 'first_name': 'Paulla', 'credit_rating': 562, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1989-06-22 00:00:00'), 'ssn_no': '86-86-2883', 'model_id': 'M00100', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1991-06-22 00:00:00'), 'cust_id': 2093269256, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CS', 'gender': 'F', 'age': 27, 'vehicle_no': 86143, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xa2k\xa4o\xa7\x98\tm\xfa\x932\xdf)\x8e\xce\x8eQ\xef\xf9\x01')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'FLOWERS', 'weight': 74, 'email_id': 'Jovita@gmail.com', 'vin': 'DVN33943H102', 'pincode': 50006, 'height': 5.9, 'child1_name': 'Cora', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Springfield', 'first_name': 'Jovita', 'credit_rating': 647, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2017-01-03 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1988-01-03 00:00:00'), 'ssn_no': '20-20-5434', 'model_id': 'M00015', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1990-01-03 00:00:00'), 'cust_id': 4927435058, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'F', 'age': 29, 'vehicle_no': 60479, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '742 Evergreen Terrace'}
# ('dev', 'customer_data', None, bytearray(b'X\x9e\xe8\x079\x81=\x9bv\x91\xc0\xba\x92`X\xae\x18\xf6\xea\xc5')) {'child2_d_o_b': nan, 'spouse_name': 'Michaela', 'last_name': 'LE', 'weight': 51, 'email_id': 'Shloma@gmail.com', 'vin': '3N1AB6AP6AL715787', 'pincode': 50420, 'height': 6.2, 'child1_name': 'Anna', 'no_of_violatn': 1, 'no_of_child': 1, 'city': 'Santa Monica', 'first_name': 'Shloma', 'credit_rating': 507, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-02 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1972-07-07 00:00:00'), 'ssn_no': '13-13-1218', 'model_id': 'M00002', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1970-07-07 00:00:00'), 'cust_id': 242339097, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2005-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'M', 'age': 44, 'vehicle_no': 66714, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '834 Ocean Vista Avenue #201'}
# ('dev', 'customer_data', None, bytearray(b'\x99\xc9\x05!\xb9\xd9\xe5\xf3\xd1q\xeb\xd3\xad\xf9\xa2\xc6\x9e!\xb6\x91')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BRADFORD', 'weight': 82, 'email_id': 'Graciana@gmail.com', 'vin': '2T1BURHE5FC463977', 'pincode': 50511, 'height': 4.2, 'child1_name': 'Nancy', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Graciana', 'credit_rating': 692, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-03-03 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1972-07-01 00:00:00'), 'ssn_no': '35-35-6770', 'model_id': 'M00077', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1974-07-01 00:00:00'), 'cust_id': 6412160291, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'F', 'age': 44, 'vehicle_no': 73625, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'?\xb3]\x10\xfd\xa4\xaaj\xa7\xfa\xd5\xce\x1f\x93\x91@\x9a3\x01\x1a')) {'child2_d_o_b': nan, 'spouse_name': 'Sage', 'last_name': 'FRANCO', 'weight': 67, 'email_id': 'Thornton@gmail.com', 'vin': '2HKYF18746H557403', 'pincode': 50007, 'height': 6.7, 'child1_name': nan, 'no_of_violatn': 2, 'no_of_child': 0, 'city': 'Manhattan', 'first_name': 'Thornton', 'credit_rating': 607, 'marital_sts': 'Separated', 'child1_d_o_b': NaT, 'state': 'New York City', 'date_of_birth': Timestamp('1965-03-19 00:00:00'), 'ssn_no': '73-73-4224', 'model_id': 'M00019', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1963-03-19 00:00:00'), 'cust_id': 3583260108, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CE', 'gender': 'M', 'age': 52, 'vehicle_no': 78862, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Buy', 'country': nan, 'strt_address': '890 Fifth Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\x9a\xad\xb3\x9csL\xf2\xacq\x93"\xce\'\x9a\x04y\x98\x95\xcd\xf0')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HARRISON', 'weight': 60, 'email_id': 'Sidney@gmail.com', 'vin': nan, 'pincode': 50008, 'height': 5.2, 'child1_name': 'Louise', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Hydsberg', 'first_name': 'Sidney', 'credit_rating': 560, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-06 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1962-05-06 00:00:00'), 'ssn_no': '25-25-2807', 'model_id': 'M00046', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1964-05-06 00:00:00'), 'cust_id': 2009007839, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Gynecologist', 'class_id': 'CCLS', 'gender': 'F', 'age': 54, 'vehicle_no': 88190, 'child2_name': 'Louise', 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': nan, 'strt_address': '123 Marshall Road'}
# ('dev', 'customer_data', None, bytearray(b'\xbd\x00\xcc\xa7u\xec\x8cr0\xb6nF\x8e\x0f\x9f\x14\xbc3\x83\xcb')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'OWENS', 'weight': 90, 'email_id': 'Charnell@gmail.com', 'vin': '1LNHM87A02Y711296', 'pincode': 50602, 'height': 6.1, 'child1_name': 'Rose', 'no_of_violatn': 4, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Charnell', 'credit_rating': 743, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-30 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1970-01-08 00:00:00'), 'ssn_no': '88-88-8313', 'model_id': 'M00037', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1972-01-08 00:00:00'), 'cust_id': 8126984299, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2014-09-09 00:00:00'), 'designation': 'Professor', 'class_id': 'CS', 'gender': 'F', 'age': 47, 'vehicle_no': 81546, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'"\xcf\xb9DWR\xe6+\xbc\x1c\x13\\\xab1\x1f\x82H\x7fb\xef')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'MOORE', 'weight': 65, 'email_id': 'Dannie@gmail.com', 'vin': '3GNFK16Z65G268495', 'pincode': 51002, 'height': 5.7, 'child1_name': 'Clara', 'no_of_violatn': 2, 'no_of_child': 2, 'city': 'Salem Center', 'first_name': 'Dannie', 'credit_rating': 590, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-01-12 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1987-10-21 00:00:00'), 'ssn_no': '87-87-3709', 'model_id': 'M00014', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1989-10-21 00:00:00'), 'cust_id': 3010547079, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Administrator', 'class_id': 'CC', 'gender': 'F', 'age': 29, 'vehicle_no': 90071, 'child2_name': 'Clara', 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'\xd4\xfd\x1b,\x8c}\x94\x8d\xbdi6\xfb\xe0\x15\xc1\xa5\xaf\x98gQ')) {'child2_d_o_b': nan, 'spouse_name': 'Scarlette', 'last_name': 'HOBBS', 'weight': 68, 'email_id': 'Lugene@gmail.com', 'vin': '1GCGK13U83F242954', 'pincode': 50603, 'height': 4.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': nan, 'first_name': 'Lugene', 'credit_rating': 611, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1981-08-15 00:00:00'), 'ssn_no': '14-14-4343', 'model_id': 'M00080', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1979-08-15 00:00:00'), 'cust_id': 3715310229, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'M', 'age': 35, 'vehicle_no': 69078, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '803 N. Dutton Drive'}
# ('dev', 'customer_data', None, bytearray(b'\xd7\x00\xf1\xfad\x93\xb7*U?\x08\x82\x99)G\x05\xf4qH\xb4')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'MORA', 'weight': 92, 'email_id': 'Luberta@gmail.com', 'vin': 'KAW20660E111', 'pincode': 51003, 'height': 5.7, 'child1_name': 'Nettie', 'no_of_violatn': 2, 'no_of_child': 1, 'city': 'Rego Park', 'first_name': 'Luberta', 'credit_rating': 755, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2015-08-22 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1986-08-22 00:00:00'), 'ssn_no': '81-81-8675', 'model_id': 'M00065', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1988-08-22 00:00:00'), 'cust_id': 8529245634, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CSL', 'gender': 'F', 'age': 30, 'vehicle_no': 85497, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '3223 Aberdeen Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xa2"0i\x92\xc8\xaf\x1a\x91\x13+\x16=\xb2L\xb0\xe5\xd0\xd8\xe9')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'FOSTER', 'weight': 94, 'email_id': 'Jeanny@gmail.com', 'vin': '5NPDH4AE3DH251616', 'pincode': 50009, 'height': 7.0, 'child1_name': 'Lucy', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Camden', 'first_name': 'Jeanny', 'credit_rating': 769, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-13 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1976-05-03 00:00:00'), 'ssn_no': '79-79-9071', 'model_id': 'M00054', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1978-05-03 00:00:00'), 'cust_id': 8969745570, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CGLC', 'gender': 'F', 'age': 40, 'vehicle_no': 65150, 'child2_name': 'Lucy', 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\x08m\x93\xaa\xc2\xfc\x8a\xa1^*\xedw\x95\xc7n\xc4\xb9n\xfb\xa1')) {'child2_d_o_b': nan, 'spouse_name': 'Alia', 'last_name': 'ROLLINS', 'weight': 69, 'email_id': 'Jere@gmail.com', 'vin': '5N1AR1NBXBC632902', 'pincode': 52203, 'height': 5.9, 'child1_name': nan, 'no_of_violatn': 6, 'no_of_child': 0, 'city': 'Camden', 'first_name': 'Jere', 'credit_rating': 618, 'marital_sts': 'Divorced', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1980-08-30 00:00:00'), 'ssn_no': '54-54-4555', 'model_id': 'M00027', 'license_susp': 'Yes', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1978-08-30 00:00:00'), 'cust_id': 3951047982, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CS', 'gender': 'M', 'age': 36, 'vehicle_no': 73781, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '9055 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xc7\xdaEV(/\xf8\xe2o\xb9_\x85\x9cu\r\xe4\x1e\xe0D\x87')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GRAVES', 'weight': 56, 'email_id': 'Valta@gmail.com', 'vin': 'KMHDU46D19U688986', 'pincode': 52203, 'height': 6.0, 'child1_name': 'Minnie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Camden', 'first_name': 'Valta', 'credit_rating': 540, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-01-05 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1988-07-24 00:00:00'), 'ssn_no': '62-62-2206', 'model_id': 'M00006', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1990-07-24 00:00:00'), 'cust_id': 1340761503, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CC', 'gender': 'F', 'age': 28, 'vehicle_no': 77511, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xf7\xc4\xfd\xe2au\xde\xf8\xecF\xf5\x9f\x8d\x9bd%\xc065\xce')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'CAMPBELL', 'weight': 60, 'email_id': 'Maggie@yahoo.com', 'vin': '1C4PJMCS8FW664777', 'pincode': 50010, 'height': 4.9, 'child1_name': 'Emma', 'no_of_violatn': 2, 'no_of_child': 1, 'city': 'New York City', 'first_name': 'Maggie', 'credit_rating': 562, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-01-03 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1983-02-19 00:00:00'), 'ssn_no': '60-60-2863', 'model_id': 'M00003', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1985-02-19 00:00:00'), 'cust_id': 2071190194, 'no_of_accidnt': 3, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'F', 'age': 34, 'vehicle_no': 70847, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '704 Hauser Street'}
# ('dev', 'customer_data', None, bytearray(b'mb\xd9\x0b\xceq\xf0\xa6/I\xf9\x89\xde\xd2XQ\xd8\xff\xb0\xe2')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'ANDREWS', 'weight': 59, 'email_id': 'Carole@yahoo.com', 'vin': '2GNALDEC0B1159038', 'pincode': 52205, 'height': 5.6, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Los Angeles', 'first_name': 'Carole', 'credit_rating': 554, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1950-04-03 00:00:00'), 'ssn_no': '76-76-2623', 'model_id': 'M00061', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1952-04-03 00:00:00'), 'cust_id': 1804203393, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Pediatrician', 'class_id': 'CGLE', 'gender': 'F', 'age': 67, 'vehicle_no': 82049, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '4222 Clinton Way'}
# ('dev', 'customer_data', None, bytearray(b'\xa0D\xc5vB\xcb1\xd4\x07\xb6\xce\xc7u\x97\xe9B\xfd\xda\xef\x13')) {'child2_d_o_b': nan, 'spouse_name': 'Gloria', 'last_name': 'WELCH', 'weight': 56, 'email_id': 'Junuis@yahoo.com', 'vin': '1FTSX2B56AEA09279', 'pincode': 51652, 'height': 4.4, 'child1_name': 'Ellen', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Junuis', 'credit_rating': 536, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-03-02 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1959-01-23 00:00:00'), 'ssn_no': '70-70-2091', 'model_id': 'M00076', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1957-01-23 00:00:00'), 'cust_id': 1213351171, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'M', 'age': 58, 'vehicle_no': 80733, 'child2_name': 'Ellen', 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '25 West 68th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xbc~\x1f\xd1\xd2\xf1\x01\x93$U\x06\xec\x88f\xf3\xb8\xce\xd8\xf6\xa0')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BAIRD', 'weight': 98, 'email_id': 'Shamora@yahoo.com', 'vin': '1G4GA5ED3BF272994', 'pincode': 52701, 'height': 5.6, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Rego Park', 'first_name': 'Shamora', 'credit_rating': 788, 'marital_sts': 'Separated', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1965-06-15 00:00:00'), 'ssn_no': '49-49-9640', 'model_id': 'M00094', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1967-06-15 00:00:00'), 'cust_id': 9601344591, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CE', 'gender': 'F', 'age': 51, 'vehicle_no': 80485, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '3223 Aberdeen Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xefF\x17` \xfa]\x114\xa4\nq\x11\xa7\xd3\xf7\xbcV\xe1E')) {'child2_d_o_b': nan, 'spouse_name': 'Sabrina', 'last_name': 'HOOVER', 'weight': 83, 'email_id': 'Robi@yahoo.com', 'vin': '1FADP3F27FL303930', 'pincode': 52030, 'height': 6.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Springfield', 'first_name': 'Robi', 'credit_rating': 703, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1969-05-17 00:00:00'), 'ssn_no': '90-90-7105', 'model_id': 'M00048', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1967-05-17 00:00:00'), 'cust_id': 6784656776, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2013-09-09 00:00:00'), 'designation': 'CFO', 'class_id': 'CGLA', 'gender': 'M', 'age': 47, 'vehicle_no': 86518, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '1000 Mammon Lane'}
# ('dev', 'customer_data', None, bytearray(b'\xef\x8b\xe2a\x8f\xc7\r\xe6XX)\x7f\xe5\xfe"\xda:`\xcc\x83')) {'child2_d_o_b': nan, 'spouse_name': 'Raelynn', 'last_name': 'MAXWELL', 'weight': 82, 'email_id': 'Ellis@yahoo.com', 'vin': '1GNEK13Z14R100603', 'pincode': 50020, 'height': 5.5, 'child1_name': 'Daisy', 'no_of_violatn': 3, 'no_of_child': 1, 'city': 'Manhattan', 'first_name': 'Ellis', 'credit_rating': 693, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-17 00:00:00'), 'state': 'New York City', 'date_of_birth': Timestamp('1985-10-26 00:00:00'), 'ssn_no': '51-51-6796', 'model_id': 'M00059', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1983-10-26 00:00:00'), 'cust_id': 6441436193, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CGLE', 'gender': 'M', 'age': 31, 'vehicle_no': 87378, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '890 Fifth Avenue'}
# ('dev', 'customer_data', None, bytearray(b"\xecf\x98Y\xdc\x84T\xf9\xa9\x98\x85\xdf\x95K\xb4T\'\xac\xcaH")) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'CRAIG', 'weight': 71, 'email_id': 'Vernalee@yahoo.com', 'vin': 'JF1GPAA67D2882576', 'pincode': 50021, 'height': 5.6, 'child1_name': 'Della', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Brooklyn', 'first_name': 'Vernalee', 'credit_rating': 630, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-03-07 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1992-06-29 00:00:00'), 'ssn_no': '86-86-4923', 'model_id': 'M00082', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1994-06-29 00:00:00'), 'cust_id': 4359553162, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'Radiation Onconlogist', 'class_id': 'CC', 'gender': 'F', 'age': 24, 'vehicle_no': 65661, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '328 1/2 Chauncey Street'}
# ('dev', 'customer_data', None, bytearray(b'p\xe3s\x82\xc7k\xf2"q]\x9d/\x814H\xf9\xab\xe0\xf5\x0c')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BRUCE', 'weight': 97, 'email_id': 'Erica@yahoo.com', 'vin': 'JNKCV61F39M358377', 'pincode': 51004, 'height': 5.0, 'child1_name': 'Etta', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Erica', 'credit_rating': 787, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-03-13 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1952-11-21 00:00:00'), 'ssn_no': '49-49-9623', 'model_id': 'M00089', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1954-11-21 00:00:00'), 'cust_id': 9582619573, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Cardiologist', 'class_id': 'CC', 'gender': 'F', 'age': 64, 'vehicle_no': 60887, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'Bz\x03\xfc\x9c\xfc\xc5\rg\x81\xcen_\xcf{\xda\xa3\xad\xe2\x15')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GILBERT', 'weight': 89, 'email_id': 'Rainie@yahoo.com', 'vin': '1BAKGCPA2AF271042', 'pincode': 50604, 'height': 5.0, 'child1_name': 'Maud', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Chicago', 'first_name': 'Rainie', 'credit_rating': 738, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2006-11-21 00:00:00'), 'state': 'Illinois', 'date_of_birth': Timestamp('1977-11-21 00:00:00'), 'ssn_no': nan, 'model_id': 'M00070', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1979-11-21 00:00:00'), 'cust_id': 7945598145, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2014-09-09 00:00:00'), 'designation': 'Anesthesiologist', 'class_id': 'CGLS', 'gender': 'F', 'age': 39, 'vehicle_no': 71733, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '9764 Jeopardy Lane'}
# ('dev', 'customer_data', None, bytearray(b'$/\\(h5\xd4P\x19\x92\x8d\xde\xdf\xe4\xe9\xab\x05\x9f\x9b\xa9')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'STEELE', 'weight': 65, 'email_id': 'Star@yahoo.com', 'vin': '4S3BNAE69F3053509', 'pincode': 51430, 'height': 4.3, 'child1_name': 'Grace', 'no_of_violatn': 0, 'no_of_child': 2, 'city': nan, 'first_name': 'Star', 'credit_rating': 595, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-01-19 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1981-07-29 00:00:00'), 'ssn_no': '88-88-3875', 'model_id': 'M00023', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1983-07-29 00:00:00'), 'cust_id': 3195715835, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'CFO', 'class_id': 'CE', 'gender': 'F', 'age': 35, 'vehicle_no': 76890, 'child2_name': 'Grace', 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '607 South Maple Street'}
# ('dev', 'customer_data', None, bytearray(b"\x9a\xa6*_\x89\xef\xbd\x0f\xb0\xc7W\xd7[\'(<\xa1\xf0\xdc\x89")) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'SANCHEZ', 'weight': 98, 'email_id': 'Xochi@hotmail.com', 'vin': 'JA3CR46V9NU017195', 'pincode': 51231, 'height': 6.3, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Salem Center', 'first_name': 'Xochi', 'credit_rating': 791, 'marital_sts': 'Divorced', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1986-04-17 00:00:00'), 'ssn_no': '71-71-9754', 'model_id': 'M00032', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1988-04-17 00:00:00'), 'cust_id': 9728648073, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Professor', 'class_id': 'CS', 'gender': 'F', 'age': 30, 'vehicle_no': 86310, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'\xa19\xa9\xd4\xb9s\xac\x80\x00x#\x87\xdftX\xb9 O\x9f\xa0')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BAUTISTA', 'weight': 60, 'email_id': 'Cyra@hotmail.com', 'vin': '2T2HK31U58C049076', 'pincode': 50605, 'height': 4.7, 'child1_name': 'Caroline', 'no_of_violatn': 5, 'no_of_child': 2, 'city': 'Camden', 'first_name': 'Cyra', 'credit_rating': 561, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('1983-09-07 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1954-09-07 00:00:00'), 'ssn_no': '63-63-2855', 'model_id': 'M00075', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1956-09-07 00:00:00'), 'cust_id': 2061945712, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Administrator', 'class_id': 'CC', 'gender': 'F', 'age': 62, 'vehicle_no': 78393, 'child2_name': 'Caroline', 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xbe\xc4Q\xb3[\xbe\x96\xf1\xfe\xe0|.E\xe8\xc8\x9cT\xc6\xd2Z')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'YODER', 'weight': 50, 'email_id': 'Josephine@hotmail.com', 'vin': '1JCMT7746JT116201', 'pincode': 51520, 'height': 6.8, 'child1_name': 'Helen', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Hollywood', 'first_name': 'Josephine', 'credit_rating': 501, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2027-07-25 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1998-07-25 00:00:00'), 'ssn_no': '87-87-1039', 'model_id': 'M00035', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('2000-07-25 00:00:00'), 'cust_id': 44261559, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2005-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CS', 'gender': 'F', 'age': 18, 'vehicle_no': 68579, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'J.\xa2\x06c\xf8\x8a\xf7\xcb\xcd\x19\x1bB*2\xf6\xc3\x199d')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LYNN', 'weight': 78, 'email_id': 'Saydee@hotmail.com', 'vin': '2HKYF18684H533335', 'pincode': 50830, 'height': 4.1, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Salem Center', 'first_name': 'Saydee', 'credit_rating': 671, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1966-12-06 00:00:00'), 'ssn_no': '75-75-6150', 'model_id': 'M00043', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1968-12-06 00:00:00'), 'cust_id': 5723075747, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CCLA', 'gender': 'F', 'age': 50, 'vehicle_no': 71684, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'Y"\xc1\xb9\x8a~\xc6\xeb\x95\xfa\xe4\xc8A)c1\xeec\xa3\xc7')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HOGAN', 'weight': 66, 'email_id': 'Suhaila@hotmail.com', 'vin': '3GYFNBE34FS595795', 'pincode': 50606, 'height': 6.8, 'child1_name': 'Josephine', 'no_of_violatn': 2, 'no_of_child': 1, 'city': nan, 'first_name': 'Suhaila', 'credit_rating': 596, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-02-19 00:00:00'), 'state': 'New Jersey', 'date_of_birth': Timestamp('1990-12-19 00:00:00'), 'ssn_no': '38-38-3880', 'model_id': 'M00062', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1992-12-19 00:00:00'), 'cust_id': 3200465361, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CGLE', 'gender': 'F', 'age': 26, 'vehicle_no': 69452, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '633 Stag Trail Road in North Caldwell'}
# ('dev', 'customer_data', None, bytearray(b'n\xe4\x9f\x94V.\x042\xe9\x1dxa*d\xce\\\x89I\xf9\xb3')) {'child2_d_o_b': nan, 'spouse_name': 'Arden', 'last_name': 'COOKE', 'weight': 55, 'email_id': 'Croy@hotmail.com', 'vin': 'WDBRF40J35A783885', 'pincode': 50514, 'height': 4.4, 'child1_name': nan, 'no_of_violatn': 1, 'no_of_child': 0, 'city': 'New York', 'first_name': 'Croy', 'credit_rating': 535, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1980-08-30 00:00:00'), 'ssn_no': '82-82-2058', 'model_id': 'M00011', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1978-08-30 00:00:00'), 'cust_id': 1176389539, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'M', 'age': 36, 'vehicle_no': 65926, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '86th floor of "the skyscraper" (implicitly the Empire State Building)'}
# ('dev', 'customer_data', None, bytearray(b"\xc7S\xcd\x00\xa1\xfb\x86!C{\x83\xab\xf1\xb8\xfa\x0ef\xc7\'\xba")) {'child2_d_o_b': nan, 'spouse_name': 'Bridget', 'last_name': 'OROZCO', 'weight': 93, 'email_id': 'Beauford@hotmail.com', 'vin': '1N4AL3AP2DC235700', 'pincode': 51331, 'height': 6.4, 'child1_name': 'Mattie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Beauford', 'credit_rating': 763, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-01-29 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1995-11-08 00:00:00'), 'ssn_no': '27-27-8903', 'model_id': 'M00036', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1993-11-08 00:00:00'), 'cust_id': 8782507386, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CS', 'gender': 'M', 'age': 21, 'vehicle_no': 80770, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xa7\xd3[\xce3k\xb1\xce{\xe4\xad\xd6\xb4;\xdf"r\xcc\x16(')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LANDRY', 'weight': 68, 'email_id': 'Amarea@hotmail.com', 'vin': nan, 'pincode': 51431, 'height': 4.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': nan, 'first_name': 'Amarea', 'credit_rating': 612, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1966-04-08 00:00:00'), 'ssn_no': '87-87-4380', 'model_id': 'M00063', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1968-04-08 00:00:00'), 'cust_id': 3756541463, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CSLC', 'gender': 'F', 'age': 50, 'vehicle_no': 59700, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '2354 Pacific Coast Highway'}
# ('dev', 'customer_data', None, bytearray(b'v\xf0v\xc0\x7fq\xf8\x00n\x9854\xe0\xc9\xc7\x0b\x03O\x8c4')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'SCHWARTZ', 'weight': 83, 'email_id': 'Anais@hotmail.com', 'vin': '1FDXE45F83HB93438', 'pincode': 52002, 'height': 4.5, 'child1_name': 'Maggie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': nan, 'first_name': 'Anais', 'credit_rating': 698, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-02-15 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1995-03-25 00:00:00'), 'ssn_no': '64-64-6954', 'model_id': 'M00057', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1997-03-25 00:00:00'), 'cust_id': 6617387789, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CGLE', 'gender': 'F', 'age': 22, 'vehicle_no': 78567, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': 'Cemetery Ridge, USA'}
# ('dev', 'customer_data', None, bytearray(b'B\xca\x8d\x14l\xf3|\xf7\x12"8>\x99\xb7\xf49u\x8b$\x1a')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HARRIS', 'weight': 60, 'email_id': 'Vianka@hotmail.com', 'vin': '5FNYF48549B036300', 'pincode': 51232, 'height': 5.1, 'child1_name': 'Nettie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Vianka', 'credit_rating': 562, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-03-06 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1990-03-13 00:00:00'), 'ssn_no': '15-15-2884', 'model_id': 'M00081', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1992-03-13 00:00:00'), 'cust_id': 2094139645, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'F', 'age': 27, 'vehicle_no': 86574, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '86th floor of "the skyscraper" (implicitly the Empire State Building)'}
# ('dev', 'customer_data', None, bytearray(b'\xe6\xf2\xa2.\xf2\x8f\xe7\x1f]\xdf\x07J?!k\xa8\xb7\xda\n\x15')) {'child2_d_o_b': nan, 'spouse_name': 'Ivanna', 'last_name': 'TRAN', 'weight': 94, 'email_id': 'Santana@hotmail.com', 'vin': 'P855H8029', 'pincode': 51432, 'height': 5.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Brooklyn', 'first_name': 'Santana', 'credit_rating': 769, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1962-06-17 00:00:00'), 'ssn_no': '60-60-9092', 'model_id': 'M00021', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1960-06-17 00:00:00'), 'cust_id': 8992995570, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Gynecologist', 'class_id': 'CE', 'gender': 'M', 'age': 54, 'vehicle_no': 76684, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '10 Stigwood Avenue'}
# ('dev', 'customer_data', None, bytearray(b"\xad\xdc\x16\x0e7\x01\x85\xee\xd3\xd9\x9e\x9e2\x89\xa6\x9d\'\xfd\x9e\xb1")) {'child2_d_o_b': nan, 'spouse_name': 'Maeve', 'last_name': 'ARMSTRONG', 'weight': 64, 'email_id': 'Alvis@hotmail.com', 'vin': '1HGCM56306A057853', 'pincode': 52720, 'height': 6.0, 'child1_name': 'Susan', 'no_of_violatn': 1, 'no_of_child': 1, 'city': 'Hollywood', 'first_name': 'Alvis', 'credit_rating': 585, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-03-21 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1976-08-04 00:00:00'), 'ssn_no': '44-44-3573', 'model_id': 'M00099', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1974-08-04 00:00:00'), 'cust_id': 2860271122, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Professor', 'class_id': 'CE', 'gender': 'M', 'age': 40, 'vehicle_no': 60920, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'2\xed\xf8\xa1z\x1c\x9b&0\xbf\xaa\xe0\xb3\x8f\xf4\x8a\xf0\xb3\x7f\xe0')) {'child2_d_o_b': nan, 'spouse_name': 'Danica', 'last_name': 'GAINES', 'weight': 79, 'email_id': 'Jassiah@hotmail.com', 'vin': '5Y2SM67099Z467769', 'pincode': 50836, 'height': 6.8, 'child1_name': 'Lena', 'no_of_violatn': 2, 'no_of_child': 1, 'city': nan, 'first_name': 'Jassiah', 'credit_rating': 676, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-02-12 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1975-10-14 00:00:00'), 'ssn_no': '14-14-6291', 'model_id': 'M00053', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1973-10-14 00:00:00'), 'cust_id': 5880471847, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'Administrator', 'class_id': 'CGLC', 'gender': 'M', 'age': 41, 'vehicle_no': 86579, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '711 Maple Street'}
# ...
# ('dev', 'customer_data', None, bytearray(b'\x14\x1c\x7f\xbbg 6\xee\x8f\x14jR\xc7&\xdb\xa4\xd1\xb9\xecc')) {'child2_d_o_b': nan, 'spouse_name': 'Frankie', 'last_name': 'RIGGS', 'weight': 70, 'email_id': 'Dvante@gmail.com', 'vin': '2FMDK4KC1ABA19940', 'pincode': 50033, 'height': 7.0, 'child1_name': 'Florence', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Dvante', 'credit_rating': 620, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-14 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1977-03-27 00:00:00'), 'ssn_no': '37-37-4617', 'model_id': 'M00017', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1975-03-27 00:00:00'), 'cust_id': 4020344733, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'Administrator', 'class_id': 'CE', 'gender': 'M', 'age': 40, 'vehicle_no': 64968, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xd7\x1e`\x08}\x19\tM\xfaw\xd8\xee\xee\xc8V\xbe\xb4\xad\xc1\xaf')) {'child2_d_o_b': nan, 'spouse_name': 'Zara', 'last_name': 'COFFEY', 'weight': 82, 'email_id': 'Doy@gmail.com', 'vin': 'F10YCR23997', 'pincode': 52535, 'height': 6.4, 'child1_name': 'Blanche', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Doy', 'credit_rating': 694, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-02-28 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1990-12-30 00:00:00'), 'ssn_no': '78-78-6840', 'model_id': 'M00073', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1988-12-30 00:00:00'), 'cust_id': 6490479961, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CG', 'gender': 'M', 'age': 26, 'vehicle_no': 63968, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '454 West 35th Street'}
# ('dev', 'customer_data', None, bytearray(b'w\xc0\x82:\xa9\x18\xbaT\xafG\x82[b\xc1\xa1\x03\xcc^\xff4')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BAIRD', 'weight': 54, 'email_id': 'Vaneka@gmail.com', 'vin': 'ARJ01769B494', 'pincode': 50034, 'height': 6.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Camden', 'first_name': 'Vaneka', 'credit_rating': 528, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1958-01-21 00:00:00'), 'ssn_no': '63-63-1861', 'model_id': 'M00095', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1960-01-21 00:00:00'), 'cust_id': 956851195, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CE', 'gender': 'F', 'age': 59, 'vehicle_no': 68056, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\x96&\xde\xe2,\x02\xd6\xcbqp\x0f\xecK\xb2o\x9e\x8dS\xd6e')) {'child2_d_o_b': nan, 'spouse_name': 'Elena', 'last_name': 'RAMIREZ', 'weight': 66, 'email_id': 'Joshawn@yahoo.com', 'vin': 'JN1CA21D9ST056384', 'pincode': 52209, 'height': 6.3, 'child1_name': 'Marie', 'no_of_violatn': 4, 'no_of_child': 2, 'city': 'Hill Valley', 'first_name': 'Joshawn', 'credit_rating': 598, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-02-24 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1981-04-25 00:00:00'), 'ssn_no': '17-17-3954', 'model_id': 'M00068', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1979-04-25 00:00:00'), 'cust_id': 3283505055, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CSL', 'gender': 'M', 'age': 35, 'vehicle_no': 63676, 'child2_name': 'Marie', 'eye_and_hair': 'Blue', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '1640 Riverside Drive'}
# ('dev', 'customer_data', None, bytearray(b'~\x1a\xb2\x02v\xf8\xc3\xb1Yt\xc4\xb1\xdc\x1d\xe6\xe2\xbff\x81\xb1')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'AUSTIN', 'weight': 96, 'email_id': 'Jacolyn@yahoo.com', 'vin': 'JTJGW31U972001837', 'pincode': 52536, 'height': 6.9, 'child1_name': 'Josephine', 'no_of_violatn': 2, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Jacolyn', 'credit_rating': 779, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2009-11-20 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1980-11-20 00:00:00'), 'ssn_no': '23-23-9395', 'model_id': 'M00050', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1982-11-20 00:00:00'), 'cust_id': 9329017447, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CGLC', 'gender': 'F', 'age': 36, 'vehicle_no': 80799, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'{K\xc4\x13R\xbd6&\xa8\xaf\x04\x03\xe8\xb8z\xe5\xc7\x81G\xe8')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'MAYS', 'weight': 99, 'email_id': 'Marles@yahoo.com', 'vin': 'JS2YB5A37A6310041', 'pincode': 51630, 'height': 5.2, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Salem Center', 'first_name': 'Marles', 'credit_rating': 798, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1981-07-29 00:00:00'), 'ssn_no': nan, 'model_id': 'M00051', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1983-07-29 00:00:00'), 'cust_id': 9963407164, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CGLC', 'gender': 'F', 'age': 35, 'vehicle_no': 66585, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'\xdf\xb2/\x04\xbeh\x19q\xc0\n\xcde\x0eF\xf7\x93\x8c\x0c\xb4}')) {'child2_d_o_b': nan, 'spouse_name': 'Amaris', 'last_name': 'MCLEAN', 'weight': 76, 'email_id': 'Auburn@yahoo.com', 'vin': '1N4DL01D9WC221703', 'pincode': 51523, 'height': 6.0, 'child1_name': 'Gertrude', 'no_of_violatn': 1, 'no_of_child': 1, 'city': 'Brooklyn', 'first_name': 'Auburn', 'credit_rating': 658, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('1981-11-17 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1952-11-17 00:00:00'), 'ssn_no': '45-45-5754', 'model_id': 'M00025', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1950-11-17 00:00:00'), 'cust_id': 5283226484, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Neurologist', 'class_id': 'CS', 'gender': 'M', 'age': 64, 'vehicle_no': 81355, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '10 Stigwood Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xe7\x92\xee\xda!\xcd\x18\x86\x11\xa3\xeb\x9e\xe5|\xc2\x1d\xf3O\x0f}')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HOUSTON', 'weight': 73, 'email_id': 'Kejuana@yahoo.com', 'vin': '1FMZU73E34UB70892', 'pincode': 50836, 'height': 5.2, 'child1_name': 'Hattie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Kejuana', 'credit_rating': 640, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-01-27 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1972-01-02 00:00:00'), 'ssn_no': '31-31-5221', 'model_id': 'M00033', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1974-01-02 00:00:00'), 'cust_id': 4691335523, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'Cardiologist', 'class_id': 'CS', 'gender': 'F', 'age': 45, 'vehicle_no': 62612, 'child2_name': nan, 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'\\\xba\xb9\x13\xd4\xd4-\xe0\x05\x87c\xbf\x15;\xaa2\x93\x8aT\xbe')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GAY', 'weight': 75, 'email_id': 'Johnna@yahoo.com', 'vin': '4T1BD1FK8EU122581', 'pincode': 52537, 'height': 4.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Vista', 'first_name': 'Johnna', 'credit_rating': 653, 'marital_sts': 'Separated', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1992-06-05 00:00:00'), 'ssn_no': '34-34-5612', 'model_id': 'M00069', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1994-06-05 00:00:00'), 'cust_id': 5125407632, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Anesthesiologist', 'class_id': 'CGLS', 'gender': 'F', 'age': 24, 'vehicle_no': 60028, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '834 Ocean Vista Avenue #201'}
# ('dev', 'customer_data', None, bytearray(b'37\x04\x9cz\xc2y\xe8u\xd6\x04\x07\xf8M\xe8\xb4\x8f\x11\xc9\x13')) {'child2_d_o_b': nan, 'spouse_name': 'Veda', 'last_name': 'MEYER', 'weight': 98, 'email_id': 'Cliffton@yahoo.com', 'vin': '1FADP3F29EL434999', 'pincode': 52726, 'height': 5.8, 'child1_name': 'Ada', 'no_of_violatn': 5, 'no_of_child': 1, 'city': 'Springfield', 'first_name': 'Cliffton', 'credit_rating': 788, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-02 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1960-07-25 00:00:00'), 'ssn_no': '90-90-9643', 'model_id': 'M00041', 'license_susp': 'Yes', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1958-07-25 00:00:00'), 'cust_id': 9605404937, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CCLA', 'gender': 'M', 'age': 56, 'vehicle_no': 86881, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '742 Evergreen Terrace,'}
# ('dev', 'customer_data', None, bytearray(b'g\x03\x85\xcc\xe8m\x8d\x07\xc9\x7f\xb0\xd3Zk{\x97c\xf2\x1d\x95')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BARTON', 'weight': 62, 'email_id': 'Tyquesha@yahoo.com', 'vin': '1HGCR2F36FA160565', 'pincode': 50519, 'height': 5.9, 'child1_name': 'Myrtle', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Tyquesha', 'credit_rating': 573, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-09 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1983-04-27 00:00:00'), 'ssn_no': '57-57-3196', 'model_id': 'M00049', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1985-04-27 00:00:00'), 'cust_id': 2440506506, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CGLA', 'gender': 'F', 'age': 33, 'vehicle_no': 71188, 'child2_name': nan, 'eye_and_hair': 'Black', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '8 Remsen Drive, Brooklyn Heights'}
# ('dev', 'customer_data', None, bytearray(b'\xb5\xd8L\xdbX\x8e\xf1\x9c\x88\x89\xcaC\xa7\x9f\x95\\\x84W\x80\xe3')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'CONTRERAS', 'weight': 95, 'email_id': 'Mercedes@yahoo.com', 'vin': '2B4GP44G7YR596036', 'pincode': 50448, 'height': 6.7, 'child1_name': 'Edna', 'no_of_violatn': 4, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Mercedes', 'credit_rating': 773, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-14 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1965-05-29 00:00:00'), 'ssn_no': '45-45-9200', 'model_id': 'M00056', 'license_susp': 'No', 'job_type': 'Professional', 'spouse_d_o_b': Timestamp('1967-05-29 00:00:00'), 'cust_id': 9112386251, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Research Scientist', 'class_id': 'CGLE', 'gender': 'F', 'age': 51, 'vehicle_no': 61537, 'child2_name': 'Edna', 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xd0\xc0S\xfd\xf5\xff\x07{\x0b\xa2\x9c\xc5\xc7\xbf\xe2\x9fI\x89\x96\xf9')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GOODWIN', 'weight': 94, 'email_id': 'Lanore@yahoo.com', 'vin': 'SALTY12412A766109', 'pincode': 52620, 'height': 4.6, 'child1_name': 'Belle', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Lanore', 'credit_rating': 767, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2026-01-02 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1997-01-02 00:00:00'), 'ssn_no': '79-79-9034', 'model_id': 'M00090', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1999-01-02 00:00:00'), 'cust_id': 8928475822, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'CEO', 'class_id': 'CC', 'gender': 'F', 'age': 20, 'vehicle_no': 77300, 'child2_name': 'Belle', 'eye_and_hair': 'Blue', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '1049 Park Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xb4\x9cI\xf1\x08\xca\x96\x19\\\xc0D\xf3m!\xbdv\x04\x03\xd1\xfa')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HANCOCK', 'weight': 77, 'email_id': 'Dashia@yahoo.com', 'vin': '5N1AR1NB8BC625561', 'pincode': 50009, 'height': 5.3, 'child1_name': 'Kate', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Springfield', 'first_name': 'Dashia', 'credit_rating': 665, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-03-20 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1994-01-04 00:00:00'), 'ssn_no': '55-55-5962', 'model_id': 'M00098', 'license_susp': 'No', 'job_type': 'Business', 'spouse_d_o_b': Timestamp('1996-01-04 00:00:00'), 'cust_id': 5514367304, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Managing Director', 'class_id': 'CE', 'gender': 'F', 'age': 23, 'vehicle_no': 60448, 'child2_name': nan, 'eye_and_hair': 'Brown', 'payment_type': 'Lease', 'country': 'USA', 'strt_address': '742 Evergreen Terrace'}
# ('dev', 'customer_data', None, bytearray(b'\xf3,\t\xd9\xc0A\x043Kr\x04\xc0F|S\x07\xa6\xdf\x07\x8e')) {'child2_d_o_b': nan, 'spouse_name': 'Aubree', 'last_name': 'WILCOX', 'weight': 61, 'email_id': 'Monroe@yahoo.com', 'vin': 'JN8AS5MV8BW261334', 'pincode': 50036, 'height': 4.5, 'child1_name': 'Eliza', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Hydsberg', 'first_name': 'Monroe', 'credit_rating': 569, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('1985-09-08 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1956-09-08 00:00:00'), 'ssn_no': '26-26-3070', 'model_id': 'M00085', 'license_susp': 'No', 'job_type': 'Government', 'spouse_d_o_b': Timestamp('1954-09-08 00:00:00'), 'cust_id': 2300372819, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Major general', 'class_id': 'CC', 'gender': 'M', 'age': 60, 'vehicle_no': 59166, 'child2_name': 'Eliza', 'eye_and_hair': 'Brown', 'payment_type': 'Buy', 'country': 'USA', 'strt_address': '123 Marshall Road'}

# %% [markdown]
# ### Create index for table dev.customer_data
#
# Syntax - CREATE INDEX numindex ON test.testset (binB) NUMERIC|STRING
#
# ###### Index 'cust_id'
# create index i_cust_id on dev.customer_data (cust_id) numeric
#
# ###### Index 'vehicle_no'
# create index i_vehicle_no on dev.customer_data (vehicle_no) numeric
