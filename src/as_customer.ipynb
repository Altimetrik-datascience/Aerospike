# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
Prepare consolidated data

"""

# Import libraries

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import pandas as pd
import aerospike
import json

print(__doc__)

class Consolidate:
    
    def __init__(self):
        pass
        
    def read(self, file):
        data = pd.read_excel(file)
        return data

    def clean_data(self, data):
    
        # Select numeric data alone from data object
        numeric_data = data.loc[:, data.dtypes != object]
    
        # Select string data alone from data object to trim
        trim_data = data.select_dtypes(['object'])
    
        # Trim all string objects
        trim_data = trim_data.apply(lambda x: x.str.strip())
    
        # Merge numeric and string data in to data object
        data = pd.concat([numeric_data, trim_data], axis=1)
    
        # Change column name to lower case
        data.columns = [x.lower() for x in data.columns]
        return data
    
    def load_data(self, data):
            
        # Split dataframe into key and records
        key = data['cust_id']
    
        record_json = data.to_dict(orient='records')
    
        config = {
            'hosts': [ ('127.0.0.1', 3000) ]
        }

        # Create a client and connect it to the cluster
        try:
            client = aerospike.client(config).connect()
        except:
            import sys
            print("failed to connect to the cluster with", config['hosts'])
            sys.exit(1)
    
        # Records are addressable via a tuple of (namespace, set, key)
        for pk, bin in zip(key, record_json):
            string = "('dev', 'customer_data', "
            string +=`pk`
            string = string + ")"
        
            from ast import literal_eval as make_tuple
            string = make_tuple(string)
        
            try:
                client = aerospike.client(config).connect()
                # Write a record
                client.put(string, bin)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)

            # Read a record after insert for verification
            (key, metadata, record) = client.get(string)
            print (key, record)
        
            # Close the connection to the Aerospike cluster
            client.close()
    
    def remove_data(self, data):

        key = data['cust_id']
    
        config = {
          'hosts': [ ('127.0.0.1', 3000) ]
        }

        # Create a client and connect it to the cluster
        try:
            client = aerospike.client(config).connect()
        except:
            import sys
            print("failed to connect to the cluster with", config['hosts'])
            sys.exit(1)
    
        # Records are addressable via a tuple of (namespace, set, key)
        for pk in key:
            string = "('dev', 'customer_data', "
            string +=`pk`
            string = string + ")"
        
            from ast import literal_eval as make_tuple
            string = make_tuple(string)
        
            try:
                client = aerospike.client(config).connect()
                # Remove a record
                client.remove(string)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)

            # Close the connection to the Aerospike cluster
            client.close()
    
def drive(mode):
    
    cons = Consolidate()

    # Read customer details excel
    data1 = cons.read("/home/azureuser/Aerospike/data/customer/customer details.xls")
    
    # Clean data1
    data1 = cons.clean_data(data1)
    #print (data1.columns)
    
    # Read Customer vehicle excel
    data2 = cons.read("/home/azureuser/Aerospike/data/customer/Customer_vehicle.xls")
    
    # Clean data2
    data2 = cons.clean_data(data2)
    #print (data2.columns)
    
    # Merge data1 and data2 by cust_id
    data2 = pd.merge(data1, data2, on='cust_id', how='inner')
    
    # Read Motor vehicle report excel
    data3 = cons.read("/home/azureuser/Aerospike/data/customer/Motor_vehicle_report.xls")
    
    # Clean data3
    data3 = cons.clean_data(data3)
    
    # Merge data2 and data3 by vehicle_no
    data3 = pd.merge(data2, data3, on='vehicle_no', how='inner')
    #print (data3.columns)
    
    # Read Customer address excel
    data4 = cons.read("/home/azureuser/Aerospike/data/customer/customer_address.xls")
    
    # Clean data4
    data4 = cons.clean_data(data4)
    
    # Merge data3 and data4 by cust_id
    data4 = pd.merge(data3, data4, on='cust_id', how='inner')
    #print (data4.columns)
    #print (data4.count)
    
    if mode == 'load':
        # Load data in to aerospike
        cons.load_data(data4)
    else:
        # Remove data from aerospike
        cons.remove_data(data4)
    
if __name__ == '__main__':
    drive('load')
# Out:
# Prepare consolidated data
#
#
# ('dev', 'customer_data', None, bytearray(b"\xdb\xb4\xe0\x9d\xcd\'\x02\x81\xdd*p\xdc\xa3\xd6\x80\t\x9e\xa3\x01\x90")) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LOWE', 'weight': 61, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 52531, 'height': 6.8, 'child1_name': 'Lillian', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Chicago', 'first_name': 'Quatasia', 'gender_x': 'F', 'credit_rating': 571, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-01 00:00:00'), 'state': 'Illinois', 'date_of_birth': Timestamp('1982-10-21 00:00:00'), 'ssn_no': '65-65-3156', 'model_id': 'M00039', 'license_susp': 'No', 'vin': 'SHSRD78494U256469', 'spouse_d_o_b': Timestamp('1984-10-21 00:00:00'), 'cust_id': 2396305636, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CTO', 'dob': Timestamp('1982-10-21 00:00:00'), 'country': 'USA', 'age': 34, 'vehicle_no': 76990, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CCLA', 'payment_type': 'Buy', 'strt_address': '715 Calhoun Street'}
# ('dev', 'customer_data', None, bytearray(b'x\xe7\x1aw\xf2\xf5\xb6 \xa2P\n\xc8*\xd5@\xbf|\xb8\x9f"')) {'child2_d_o_b': nan, 'spouse_name': 'Abril', 'last_name': 'CROSS', 'weight': 50, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50001, 'height': 4.8, 'child1_name': 'Sarah', 'no_of_violatn': 0, 'no_of_child': 1, 'city': nan, 'first_name': 'Elia', 'gender_x': 'M', 'credit_rating': 502, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-10 00:00:00'), 'state': 'Bluffington', 'date_of_birth': Timestamp('1988-02-07 00:00:00'), 'ssn_no': '95-95-1076', 'model_id': 'M00012', 'license_susp': 'No', 'vin': '2C3CA5CG5BH552838', 'spouse_d_o_b': Timestamp('1986-02-07 00:00:00'), 'cust_id': 84711641, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2005-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1988-02-07 00:00:00'), 'country': 'USA', 'age': 29, 'vehicle_no': 67623, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '21 Jumbo Street'}
# ('dev', 'customer_data', None, bytearray(b'\xa9\xab\xc6OB\x13\xe7\x12&\xf72\x06\xbdM\xdc<^\xbf+\x8c')) {'child2_d_o_b': nan, 'spouse_name': 'Yamileth', 'last_name': 'MONTES', 'weight': 57, 'gender_y': 'M', 'job_type': 'Government', 'pincode': 50002, 'height': 5.8, 'child1_name': 'May', 'no_of_violatn': 3, 'no_of_child': 1, 'city': 'Hollywood', 'first_name': 'Mardy', 'gender_x': 'M', 'credit_rating': 546, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-26 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1994-02-22 00:00:00'), 'ssn_no': '15-15-2405', 'model_id': 'M00071', 'license_susp': 'No', 'vin': '1G1NE52J53M570317', 'spouse_d_o_b': Timestamp('1992-02-22 00:00:00'), 'cust_id': 1561684799, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'Doctor', 'dob': Timestamp('1994-02-22 00:00:00'), 'country': 'USA', 'age': 23, 'vehicle_no': 60734, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CGLS', 'payment_type': 'Buy', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'd\x17\xba\xd4\xc0\xfb\x8e\xfb\xc4)\x17f\xea\xdd^V%\xa1\xee\xd0')) {'child2_d_o_b': nan, 'spouse_name': 'Stevie', 'last_name': 'TODD', 'weight': 95, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 50003, 'height': 6.3, 'child1_name': 'Edith', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Santa Monica', 'first_name': 'Elisandro', 'gender_x': 'M', 'credit_rating': 770, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-01-28 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1987-05-07 00:00:00'), 'ssn_no': '36-36-9105', 'model_id': 'M00034', 'license_susp': 'No', 'vin': 'G720VHP33368', 'spouse_d_o_b': Timestamp('1985-05-07 00:00:00'), 'cust_id': 9006719754, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Cardiologist', 'dob': Timestamp('1987-05-07 00:00:00'), 'country': 'USA', 'age': 29, 'vehicle_no': 65609, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '834 Ocean Vista Avenue #201'}
# ('dev', 'customer_data', None, bytearray(b'\xfc\xda\x1c\xa2q\xebL\x1a\xe9\x9ad\x17\xfc;\xd3*9\xc8\x9f\xf0')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'PARSONS', 'weight': 69, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50830, 'height': 4.6, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'New York', 'first_name': 'Lyndell', 'gender_x': 'F', 'credit_rating': 618, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1970-05-20 00:00:00'), 'ssn_no': nan, 'model_id': 'M00045', 'license_susp': 'No', 'vin': '3FAHP07Z87R279717', 'spouse_d_o_b': Timestamp('1972-05-20 00:00:00'), 'cust_id': 3947774146, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'Anesthesiologist', 'dob': Timestamp('1970-05-20 00:00:00'), 'country': 'USA', 'age': 46, 'vehicle_no': 74809, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CCLS', 'payment_type': 'Buy', 'strt_address': '25 West 68th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xbb\x96I2\xfea\x16\xc8\xb8\x93\x8b\x07|-\xc2\xb8\xda\xe8\xb6\x9d')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LUCAS', 'weight': 60, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 52530, 'height': 4.6, 'child1_name': 'Gertrude', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Los Angeles', 'first_name': 'Retta', 'gender_x': 'F', 'credit_rating': 560, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-01-25 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1963-12-05 00:00:00'), 'ssn_no': '44-44-2805', 'model_id': 'M00031', 'license_susp': 'No', 'vin': 'STR96955J607', 'spouse_d_o_b': Timestamp('1965-12-05 00:00:00'), 'cust_id': 2006085121, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CFO', 'dob': Timestamp('1963-12-05 00:00:00'), 'country': 'USA', 'age': 53, 'vehicle_no': 59888, 'child2_name': 'Gertrude', 'eye_and_hair': 'Black', 'class_id': 'CS', 'payment_type': 'Lease', 'strt_address': '4222 Clinton Way'}
# ('dev', 'customer_data', None, bytearray(b'\x1a\x18J:\xe2\xecI8a\xbe\xdd\xddm&\xd88\x0c\xd7\xae\xed')) {'child2_d_o_b': nan, 'spouse_name': 'Hayden', 'last_name': 'CHOI', 'weight': 59, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 52201, 'height': 5.0, 'child1_name': 'Mamie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Manhattan', 'first_name': 'Lue', 'gender_x': 'M', 'credit_rating': 557, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-02-27 00:00:00'), 'state': 'New York City', 'date_of_birth': Timestamp('1954-04-26 00:00:00'), 'ssn_no': '61-61-2716', 'model_id': 'M00072', 'license_susp': 'No', 'vin': 'WBA3B5G57FNS17981', 'spouse_d_o_b': Timestamp('1952-04-26 00:00:00'), 'cust_id': 1907459679, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Professor', 'dob': Timestamp('1954-04-26 00:00:00'), 'country': 'USA', 'age': 62, 'vehicle_no': 83651, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CG', 'payment_type': 'Buy', 'strt_address': '890 Fifth Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\x99\x85\\b\xc4*\xb8\xf0q\xd2\xa6\xec\xcb\xf0\x8a\x899s\\\xb2')) {'child2_d_o_b': nan, 'spouse_name': 'Serenity', 'last_name': 'SPENCE', 'weight': 61, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 51001, 'height': 6.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Metropolis', 'first_name': 'Nolan', 'gender_x': 'M', 'credit_rating': 571, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1995-02-11 00:00:00'), 'ssn_no': '24-24-3158', 'model_id': 'M00055', 'license_susp': 'No', 'vin': 'JN1CA21A5WM805526', 'spouse_d_o_b': Timestamp('1993-02-11 00:00:00'), 'cust_id': 2398850356, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Chief Architect', 'dob': Timestamp('1995-02-11 00:00:00'), 'country': 'USA', 'age': 22, 'vehicle_no': 86773, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CGLE', 'payment_type': 'Buy', 'strt_address': '344 Clinton St., Apt. 3B'}
# ('dev', 'customer_data', None, bytearray(b'x9\x02nP\x95\xf0\r\x9a\x8b-k\xb4\xcc\xe7G\xbf\xd2R\xdc')) {'child2_d_o_b': nan, 'spouse_name': 'Presley', 'last_name': 'SPEARS', 'weight': 92, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50510, 'height': 4.2, 'child1_name': 'Rose', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Erasmo', 'gender_x': 'M', 'credit_rating': 754, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2021-10-06 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1992-10-06 00:00:00'), 'ssn_no': '87-87-8637', 'model_id': 'M00030', 'license_susp': 'No', 'vin': '1F66F5DY8F0A02001', 'spouse_d_o_b': Timestamp('1990-10-06 00:00:00'), 'cust_id': 8486613847, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1992-10-06 00:00:00'), 'country': 'USA', 'age': 24, 'vehicle_no': 89200, 'child2_name': 'Rose', 'eye_and_hair': 'Black', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '1049 Park Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xaa\\@\xcf\xd8m\x84\x8e\x0b\xd5-\x89\xcb\xbeB\xb3\x02 \xf1\xcc')) {'child2_d_o_b': nan, 'spouse_name': 'Anastasia', 'last_name': 'HANSON', 'weight': 70, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 52531, 'height': 5.2, 'child1_name': 'Harriet', 'no_of_violatn': 6, 'no_of_child': 2, 'city': 'Chicago', 'first_name': 'Leslie', 'gender_x': 'M', 'credit_rating': 625, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-03-14 00:00:00'), 'state': 'Illinois', 'date_of_birth': Timestamp('1953-08-05 00:00:00'), 'ssn_no': '69-69-4775', 'model_id': 'M00091', 'license_susp': 'Yes', 'vin': '4S3BMBG69A3244703', 'spouse_d_o_b': Timestamp('1951-08-05 00:00:00'), 'cust_id': 4195354888, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1953-08-05 00:00:00'), 'country': 'USA', 'age': 63, 'vehicle_no': 83280, 'child2_name': 'Harriet', 'eye_and_hair': 'Brown', 'class_id': 'CE', 'payment_type': 'Lease', 'strt_address': '711 Calhoun Street'}
# ('dev', 'customer_data', None, bytearray(b'\x91\x96\xd4J\x93\xc4Z\xbf\x00\x830\xfe\x03\xe8\xa8 y\xf1s\x00')) {'child2_d_o_b': nan, 'spouse_name': 'Giuliana', 'last_name': 'OLSON', 'weight': 94, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 50005, 'height': 5.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Hollywood', 'first_name': 'Flor', 'gender_x': 'M', 'credit_rating': 765, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1990-12-16 00:00:00'), 'ssn_no': nan, 'model_id': 'M00013', 'license_susp': 'No', 'vin': 'JN8AF5MV7DT223764', 'spouse_d_o_b': Timestamp('1988-12-16 00:00:00'), 'cust_id': 8833668145, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1990-12-16 00:00:00'), 'country': 'USA', 'age': 26, 'vehicle_no': 75573, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'\xbf\x83\xd4\x80_-/\xa0\xa8\x19\xea\x01\x9b\xd0\xb6\x18\x98\x1e\x15f')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'SIMS', 'weight': 60, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 52202, 'height': 6.3, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Camden', 'first_name': 'Paulla', 'gender_x': 'F', 'credit_rating': 562, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1989-06-22 00:00:00'), 'ssn_no': '86-86-2883', 'model_id': 'M00100', 'license_susp': 'No', 'vin': '1FAFP56S11A258380', 'spouse_d_o_b': Timestamp('1991-06-22 00:00:00'), 'cust_id': 2093269256, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1989-06-22 00:00:00'), 'country': 'USA', 'age': 27, 'vehicle_no': 86143, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xf2\x08\xa9n\x92\xa7\x82\xf7\xce\x93\x80e\xcf<$\xbe\xc8\x19\xc7\x90')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'FLOWERS', 'weight': 74, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50006, 'height': 5.9, 'child1_name': 'Cora', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Springfield', 'first_name': 'Jovita', 'gender_x': 'F', 'credit_rating': 647, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2017-01-03 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1988-01-03 00:00:00'), 'ssn_no': '20-20-5434', 'model_id': 'M00015', 'license_susp': 'No', 'vin': 'DVN33943H102', 'spouse_d_o_b': Timestamp('1990-01-03 00:00:00'), 'cust_id': 4927435058, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1988-01-03 00:00:00'), 'country': 'USA', 'age': 29, 'vehicle_no': 60479, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '742 Evergreen Terrace'}
# ('dev', 'customer_data', None, bytearray(b'\xb0\xeb\xab~%\x17b\xe5\xa8x\xefK\xa9M2y\x84\xd1"\x8a')) {'child2_d_o_b': nan, 'spouse_name': 'Michaela', 'last_name': 'LE', 'weight': 51, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50420, 'height': 6.2, 'child1_name': 'Anna', 'no_of_violatn': 1, 'no_of_child': 1, 'city': 'Santa Monica', 'first_name': 'Shloma', 'gender_x': 'M', 'credit_rating': 507, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-02 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1972-07-07 00:00:00'), 'ssn_no': '13-13-1218', 'model_id': 'M00002', 'license_susp': 'No', 'vin': '3N1AB6AP6AL715787', 'spouse_d_o_b': Timestamp('1970-07-07 00:00:00'), 'cust_id': 242339097, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2005-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1972-07-07 00:00:00'), 'country': 'USA', 'age': 44, 'vehicle_no': 66714, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '834 Ocean Vista Avenue #201'}
# ('dev', 'customer_data', None, bytearray(b'\xe9b\xa6\xd9\xed\xb1\xf3\xa3u\x80]2\x8el<\x1cF\x11\x97\xfa')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BRADFORD', 'weight': 82, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50511, 'height': 4.2, 'child1_name': 'Nancy', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Graciana', 'gender_x': 'F', 'credit_rating': 692, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-03-03 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1972-07-01 00:00:00'), 'ssn_no': '35-35-6770', 'model_id': 'M00077', 'license_susp': 'No', 'vin': '2T1BURHE5FC463977', 'spouse_d_o_b': Timestamp('1974-07-01 00:00:00'), 'cust_id': 6412160291, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1972-07-01 00:00:00'), 'country': 'USA', 'age': 44, 'vehicle_no': 73625, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'P\xe4[\xceT\x8at\xecV\xdf*G\xe7\xeew\xa4d\xa9}5')) {'child2_d_o_b': nan, 'spouse_name': 'Sage', 'last_name': 'FRANCO', 'weight': 67, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50007, 'height': 6.7, 'child1_name': nan, 'no_of_violatn': 2, 'no_of_child': 0, 'city': 'Manhattan', 'first_name': 'Thornton', 'gender_x': 'M', 'credit_rating': 607, 'marital_sts': 'Separated', 'child1_d_o_b': NaT, 'state': 'New York City', 'date_of_birth': Timestamp('1965-03-19 00:00:00'), 'ssn_no': '73-73-4224', 'model_id': 'M00019', 'license_susp': 'No', 'vin': '2HKYF18746H557403', 'spouse_d_o_b': Timestamp('1963-03-19 00:00:00'), 'cust_id': 3583260108, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1965-03-19 00:00:00'), 'country': nan, 'age': 52, 'vehicle_no': 78862, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CE', 'payment_type': 'Buy', 'strt_address': '890 Fifth Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xaf\xd9<\xa4\x9e}\xa8\xbd\xfbV]\x96\xb2\x1e\xaa\xc6/p\xe1\x8b')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HARRISON', 'weight': 60, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50008, 'height': 5.2, 'child1_name': 'Louise', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Hydsberg', 'first_name': 'Sidney', 'gender_x': 'F', 'credit_rating': 560, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-06 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1962-05-06 00:00:00'), 'ssn_no': '25-25-2807', 'model_id': 'M00046', 'license_susp': 'No', 'vin': nan, 'spouse_d_o_b': Timestamp('1964-05-06 00:00:00'), 'cust_id': 2009007839, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Gynecologist', 'dob': Timestamp('1962-05-06 00:00:00'), 'country': nan, 'age': 54, 'vehicle_no': 88190, 'child2_name': 'Louise', 'eye_and_hair': 'Brown', 'class_id': 'CCLS', 'payment_type': 'Buy', 'strt_address': '123 Marshall Road'}
# ('dev', 'customer_data', None, bytearray(b'\x1a\x9a\xcbH>\xdf\xd8\xbf\xe2\x1d\xdf\x12\x93\xf9\x1f\xc0\\\xae\xbc\xbc')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'OWENS', 'weight': 90, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50602, 'height': 6.1, 'child1_name': 'Rose', 'no_of_violatn': 4, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Charnell', 'gender_x': 'F', 'credit_rating': 743, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-30 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1970-01-08 00:00:00'), 'ssn_no': '88-88-8313', 'model_id': 'M00037', 'license_susp': 'No', 'vin': '1LNHM87A02Y711296', 'spouse_d_o_b': Timestamp('1972-01-08 00:00:00'), 'cust_id': 8126984299, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2014-09-09 00:00:00'), 'designation': 'Professor', 'dob': Timestamp('1970-01-08 00:00:00'), 'country': 'USA', 'age': 47, 'vehicle_no': 81546, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CS', 'payment_type': 'Lease', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'\xd1\xb3\xc8t4\xa2\x17|,\x84\x1b\xa8\xed\xf8=\x9c\xe1\x85\xe1-')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'MOORE', 'weight': 65, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 51002, 'height': 5.7, 'child1_name': 'Clara', 'no_of_violatn': 2, 'no_of_child': 2, 'city': 'Salem Center', 'first_name': 'Dannie', 'gender_x': 'F', 'credit_rating': 590, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-01-12 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1987-10-21 00:00:00'), 'ssn_no': '87-87-3709', 'model_id': 'M00014', 'license_susp': 'No', 'vin': '3GNFK16Z65G268495', 'spouse_d_o_b': Timestamp('1989-10-21 00:00:00'), 'cust_id': 3010547079, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Administrator', 'dob': Timestamp('1987-10-21 00:00:00'), 'country': 'USA', 'age': 29, 'vehicle_no': 90071, 'child2_name': 'Clara', 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'\x0c\xca\x96rw!Wv\xd5\xf4\xd1\x1f\x99\xb9\xe7,\x91\xfb\x01\xbc')) {'child2_d_o_b': nan, 'spouse_name': 'Scarlette', 'last_name': 'HOBBS', 'weight': 68, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50603, 'height': 4.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': nan, 'first_name': 'Lugene', 'gender_x': 'M', 'credit_rating': 611, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1981-08-15 00:00:00'), 'ssn_no': '14-14-4343', 'model_id': 'M00080', 'license_susp': 'No', 'vin': '1GCGK13U83F242954', 'spouse_d_o_b': Timestamp('1979-08-15 00:00:00'), 'cust_id': 3715310229, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1981-08-15 00:00:00'), 'country': 'USA', 'age': 35, 'vehicle_no': 69078, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '803 N. Dutton Drive'}
# ('dev', 'customer_data', None, bytearray(b'M\xbc;\xc0\x97\xb2\x9bj5\xa5z\xe22\xcc\x1b\xccaIl\x17')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'MORA', 'weight': 92, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 51003, 'height': 5.7, 'child1_name': 'Nettie', 'no_of_violatn': 2, 'no_of_child': 1, 'city': 'Rego Park', 'first_name': 'Luberta', 'gender_x': 'F', 'credit_rating': 755, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2015-08-22 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1986-08-22 00:00:00'), 'ssn_no': '81-81-8675', 'model_id': 'M00065', 'license_susp': 'No', 'vin': 'KAW20660E111', 'spouse_d_o_b': Timestamp('1988-08-22 00:00:00'), 'cust_id': 8529245634, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1986-08-22 00:00:00'), 'country': 'USA', 'age': 30, 'vehicle_no': 85497, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CSL', 'payment_type': 'Buy', 'strt_address': '3223 Aberdeen Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xfa\xbe\xb2\x90\xae\xd6\tK"\xca\xcf\x99!i_\x8fxW\x9f|')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'FOSTER', 'weight': 94, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50009, 'height': 7.0, 'child1_name': 'Lucy', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Camden', 'first_name': 'Jeanny', 'gender_x': 'F', 'credit_rating': 769, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-13 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1976-05-03 00:00:00'), 'ssn_no': '79-79-9071', 'model_id': 'M00054', 'license_susp': 'No', 'vin': '5NPDH4AE3DH251616', 'spouse_d_o_b': Timestamp('1978-05-03 00:00:00'), 'cust_id': 8969745570, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1976-05-03 00:00:00'), 'country': 'USA', 'age': 40, 'vehicle_no': 65150, 'child2_name': 'Lucy', 'eye_and_hair': 'Black', 'class_id': 'CGLC', 'payment_type': 'Buy', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'qi\xed\r\x8b\xc5\xc1\xcc\x11\xe3\xf2zW\x19T\xc79%$7')) {'child2_d_o_b': nan, 'spouse_name': 'Alia', 'last_name': 'ROLLINS', 'weight': 69, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 52203, 'height': 5.9, 'child1_name': nan, 'no_of_violatn': 6, 'no_of_child': 0, 'city': 'Camden', 'first_name': 'Jere', 'gender_x': 'M', 'credit_rating': 618, 'marital_sts': 'Divorced', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1980-08-30 00:00:00'), 'ssn_no': '54-54-4555', 'model_id': 'M00027', 'license_susp': 'Yes', 'vin': '5N1AR1NBXBC632902', 'spouse_d_o_b': Timestamp('1978-08-30 00:00:00'), 'cust_id': 3951047982, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1980-08-30 00:00:00'), 'country': 'USA', 'age': 36, 'vehicle_no': 73781, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '9055 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\x0e\x17\xbe\xd3\xfda\xcdGD\x92\x87\xfdG\xe1CE\x1b\x05\xe7\xf9')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GRAVES', 'weight': 56, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 52203, 'height': 6.0, 'child1_name': 'Minnie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Camden', 'first_name': 'Valta', 'gender_x': 'F', 'credit_rating': 540, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-01-05 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1988-07-24 00:00:00'), 'ssn_no': '62-62-2206', 'model_id': 'M00006', 'license_susp': 'No', 'vin': 'KMHDU46D19U688986', 'spouse_d_o_b': Timestamp('1990-07-24 00:00:00'), 'cust_id': 1340761503, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1988-07-24 00:00:00'), 'country': 'USA', 'age': 28, 'vehicle_no': 77511, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'K\x1eD\xbc@\xf4\na\x05i\xec\xd4\x9e*2\xe5Zes\x93')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'CAMPBELL', 'weight': 60, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50010, 'height': 4.9, 'child1_name': 'Emma', 'no_of_violatn': 2, 'no_of_child': 1, 'city': 'New York City', 'first_name': 'Maggie', 'gender_x': 'F', 'credit_rating': 562, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-01-03 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1983-02-19 00:00:00'), 'ssn_no': '60-60-2863', 'model_id': 'M00003', 'license_susp': 'No', 'vin': '1C4PJMCS8FW664777', 'spouse_d_o_b': Timestamp('1985-02-19 00:00:00'), 'cust_id': 2071190194, 'no_of_accidnt': 3, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1983-02-19 00:00:00'), 'country': 'USA', 'age': 34, 'vehicle_no': 70847, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '704 Hauser Street'}
# ('dev', 'customer_data', None, bytearray(b'\xa0\x91B\xa9\xe2\x90\x8f\x9aY@\xd0\x11V\x80\x0e\xc5m\xa0:\x90')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'ANDREWS', 'weight': 59, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 52205, 'height': 5.6, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Los Angeles', 'first_name': 'Carole', 'gender_x': 'F', 'credit_rating': 554, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1950-04-03 00:00:00'), 'ssn_no': '76-76-2623', 'model_id': 'M00061', 'license_susp': 'No', 'vin': '2GNALDEC0B1159038', 'spouse_d_o_b': Timestamp('1952-04-03 00:00:00'), 'cust_id': 1804203393, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Pediatrician', 'dob': Timestamp('1950-04-03 00:00:00'), 'country': 'USA', 'age': 67, 'vehicle_no': 82049, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CGLE', 'payment_type': 'Lease', 'strt_address': '4222 Clinton Way'}
# ('dev', 'customer_data', None, bytearray(b'\xe8\x9d\x01R\x1f*\xe8\xc9\x1f\xf4\x1b\r\x93\xc6C\xba\xf0\x18\xb2\xda')) {'child2_d_o_b': nan, 'spouse_name': 'Gloria', 'last_name': 'WELCH', 'weight': 56, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 51652, 'height': 4.4, 'child1_name': 'Ellen', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Junuis', 'gender_x': 'M', 'credit_rating': 536, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-03-02 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1959-01-23 00:00:00'), 'ssn_no': '70-70-2091', 'model_id': 'M00076', 'license_susp': 'No', 'vin': '1FTSX2B56AEA09279', 'spouse_d_o_b': Timestamp('1957-01-23 00:00:00'), 'cust_id': 1213351171, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1959-01-23 00:00:00'), 'country': 'USA', 'age': 58, 'vehicle_no': 80733, 'child2_name': 'Ellen', 'eye_and_hair': 'Brown', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '25 West 68th Street'}
# ('dev', 'customer_data', None, bytearray(b'\th@\xeb\xbb\xfe\xe2\xa8r\x9d\xe0\x96\x90#\x83|\xe6\x1d`\xfd')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BAIRD', 'weight': 98, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 52701, 'height': 5.6, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Rego Park', 'first_name': 'Shamora', 'gender_x': 'F', 'credit_rating': 788, 'marital_sts': 'Separated', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1965-06-15 00:00:00'), 'ssn_no': '49-49-9640', 'model_id': 'M00094', 'license_susp': 'No', 'vin': '1G4GA5ED3BF272994', 'spouse_d_o_b': Timestamp('1967-06-15 00:00:00'), 'cust_id': 9601344591, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1965-06-15 00:00:00'), 'country': 'USA', 'age': 51, 'vehicle_no': 80485, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CE', 'payment_type': 'Buy', 'strt_address': '3223 Aberdeen Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xff\x1b=\xcb\xb1)57\xe8\x12\xeb{\x89\t}s<bIr')) {'child2_d_o_b': nan, 'spouse_name': 'Sabrina', 'last_name': 'HOOVER', 'weight': 83, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 52030, 'height': 6.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Springfield', 'first_name': 'Robi', 'gender_x': 'M', 'credit_rating': 703, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1969-05-17 00:00:00'), 'ssn_no': '90-90-7105', 'model_id': 'M00048', 'license_susp': 'No', 'vin': '1FADP3F27FL303930', 'spouse_d_o_b': Timestamp('1967-05-17 00:00:00'), 'cust_id': 6784656776, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2013-09-09 00:00:00'), 'designation': 'CFO', 'dob': Timestamp('1969-05-17 00:00:00'), 'country': 'USA', 'age': 47, 'vehicle_no': 86518, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CGLA', 'payment_type': 'Buy', 'strt_address': '1000 Mammon Lane'}
# ('dev', 'customer_data', None, bytearray(b"c\xce\x1fCi\xa3\xda\x91\xcdPX2\xf4\x14\xbd\'\xea\xbeq\x90")) {'child2_d_o_b': nan, 'spouse_name': 'Raelynn', 'last_name': 'MAXWELL', 'weight': 82, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50020, 'height': 5.5, 'child1_name': 'Daisy', 'no_of_violatn': 3, 'no_of_child': 1, 'city': 'Manhattan', 'first_name': 'Ellis', 'gender_x': 'M', 'credit_rating': 693, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-17 00:00:00'), 'state': 'New York City', 'date_of_birth': Timestamp('1985-10-26 00:00:00'), 'ssn_no': '51-51-6796', 'model_id': 'M00059', 'license_susp': 'No', 'vin': '1GNEK13Z14R100603', 'spouse_d_o_b': Timestamp('1983-10-26 00:00:00'), 'cust_id': 6441436193, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1985-10-26 00:00:00'), 'country': 'USA', 'age': 31, 'vehicle_no': 87378, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLE', 'payment_type': 'Lease', 'strt_address': '890 Fifth Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xb4M\x96\x9cr^\xe3\xf2\xb3\xab\xa5#i\xc6\x19\x86)4\xbeH')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'CRAIG', 'weight': 71, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50021, 'height': 5.6, 'child1_name': 'Della', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Brooklyn', 'first_name': 'Vernalee', 'gender_x': 'F', 'credit_rating': 630, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-03-07 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1992-06-29 00:00:00'), 'ssn_no': '86-86-4923', 'model_id': 'M00082', 'license_susp': 'No', 'vin': 'JF1GPAA67D2882576', 'spouse_d_o_b': Timestamp('1994-06-29 00:00:00'), 'cust_id': 4359553162, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'Radiation Onconlogist', 'dob': Timestamp('1992-06-29 00:00:00'), 'country': 'USA', 'age': 24, 'vehicle_no': 65661, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '328 1/2 Chauncey Street'}
# ('dev', 'customer_data', None, bytearray(b'\xe54)\xf2\xa6\x97\xdf^\x16\x0b\xe1\x03\xf7L\x90x\xec\xa9\x8c\xa3')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BRUCE', 'weight': 97, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 51004, 'height': 5.0, 'child1_name': 'Etta', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Erica', 'gender_x': 'F', 'credit_rating': 787, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-03-13 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1952-11-21 00:00:00'), 'ssn_no': '49-49-9623', 'model_id': 'M00089', 'license_susp': 'No', 'vin': 'JNKCV61F39M358377', 'spouse_d_o_b': Timestamp('1954-11-21 00:00:00'), 'cust_id': 9582619573, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Cardiologist', 'dob': Timestamp('1952-11-21 00:00:00'), 'country': 'USA', 'age': 64, 'vehicle_no': 60887, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'\x9e]\x0b\x18\x08\xdd\x81jb\x96\x8aC\xa9\xec\xb17\xa4\xbf\x06\x0b')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GILBERT', 'weight': 89, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50604, 'height': 5.0, 'child1_name': 'Maud', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Chicago', 'first_name': 'Rainie', 'gender_x': 'F', 'credit_rating': 738, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2006-11-21 00:00:00'), 'state': 'Illinois', 'date_of_birth': Timestamp('1977-11-21 00:00:00'), 'ssn_no': nan, 'model_id': 'M00070', 'license_susp': 'No', 'vin': '1BAKGCPA2AF271042', 'spouse_d_o_b': Timestamp('1979-11-21 00:00:00'), 'cust_id': 7945598145, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2014-09-09 00:00:00'), 'designation': 'Anesthesiologist', 'dob': Timestamp('1977-11-21 00:00:00'), 'country': 'USA', 'age': 39, 'vehicle_no': 71733, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CGLS', 'payment_type': 'Lease', 'strt_address': '9764 Jeopardy Lane'}
# ('dev', 'customer_data', None, bytearray(b'4\x80M\xc6[\x19\xd7\xbb.\x1b\xe4\x9d\xa5\xbd=\x82S\x83\xf2\xf1')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'STEELE', 'weight': 65, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 51430, 'height': 4.3, 'child1_name': 'Grace', 'no_of_violatn': 0, 'no_of_child': 2, 'city': nan, 'first_name': 'Star', 'gender_x': 'F', 'credit_rating': 595, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-01-19 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1981-07-29 00:00:00'), 'ssn_no': '88-88-3875', 'model_id': 'M00023', 'license_susp': 'No', 'vin': '4S3BNAE69F3053509', 'spouse_d_o_b': Timestamp('1983-07-29 00:00:00'), 'cust_id': 3195715835, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'CFO', 'dob': Timestamp('1981-07-29 00:00:00'), 'country': 'USA', 'age': 35, 'vehicle_no': 76890, 'child2_name': 'Grace', 'eye_and_hair': 'Brown', 'class_id': 'CE', 'payment_type': 'Buy', 'strt_address': '607 South Maple Street'}
# ('dev', 'customer_data', None, bytearray(b'\xb5\x8c\xd4r\xb7\xfd\xbe\xa4V\xc4x\x13\xa3\xf7\xea\x9b\xefO\xda\xdd')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'SANCHEZ', 'weight': 98, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 51231, 'height': 6.3, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Salem Center', 'first_name': 'Xochi', 'gender_x': 'F', 'credit_rating': 791, 'marital_sts': 'Divorced', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1986-04-17 00:00:00'), 'ssn_no': '71-71-9754', 'model_id': 'M00032', 'license_susp': 'No', 'vin': 'JA3CR46V9NU017195', 'spouse_d_o_b': Timestamp('1988-04-17 00:00:00'), 'cust_id': 9728648073, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Professor', 'dob': Timestamp('1986-04-17 00:00:00'), 'country': 'USA', 'age': 30, 'vehicle_no': 86310, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'\xbc\xcc(\xc4\x02\xb0\x85G\x02\x97\x07\xfbz\x0e\xedQ?\xf5)\xb4')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BAUTISTA', 'weight': 60, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50605, 'height': 4.7, 'child1_name': 'Caroline', 'no_of_violatn': 5, 'no_of_child': 2, 'city': 'Camden', 'first_name': 'Cyra', 'gender_x': 'F', 'credit_rating': 561, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('1983-09-07 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1954-09-07 00:00:00'), 'ssn_no': '63-63-2855', 'model_id': 'M00075', 'license_susp': 'No', 'vin': '2T2HK31U58C049076', 'spouse_d_o_b': Timestamp('1956-09-07 00:00:00'), 'cust_id': 2061945712, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Administrator', 'dob': Timestamp('1954-09-07 00:00:00'), 'country': 'USA', 'age': 62, 'vehicle_no': 78393, 'child2_name': 'Caroline', 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xaba\x03\x86\xc2Tsm\x9a\x87\xe6\xaf<\x90\xef\x1a\x03q\x0fe')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'YODER', 'weight': 50, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 51520, 'height': 6.8, 'child1_name': 'Helen', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Hollywood', 'first_name': 'Josephine', 'gender_x': 'F', 'credit_rating': 501, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2027-07-25 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1998-07-25 00:00:00'), 'ssn_no': '87-87-1039', 'model_id': 'M00035', 'license_susp': 'No', 'vin': '1JCMT7746JT116201', 'spouse_d_o_b': Timestamp('2000-07-25 00:00:00'), 'cust_id': 44261559, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2005-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1998-07-25 00:00:00'), 'country': 'USA', 'age': 18, 'vehicle_no': 68579, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ('dev', 'customer_data', None, bytearray(b'N\xb8\x9a\xea\xcbl\xc7A\xb31\x95\xe8\x15\xf9UEyW\x9c\x1a')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LYNN', 'weight': 78, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50830, 'height': 4.1, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Salem Center', 'first_name': 'Saydee', 'gender_x': 'F', 'credit_rating': 671, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1966-12-06 00:00:00'), 'ssn_no': '75-75-6150', 'model_id': 'M00043', 'license_susp': 'No', 'vin': '2HKYF18684H533335', 'spouse_d_o_b': Timestamp('1968-12-06 00:00:00'), 'cust_id': 5723075747, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1966-12-06 00:00:00'), 'country': 'USA', 'age': 50, 'vehicle_no': 71684, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CCLA', 'payment_type': 'Lease', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b"\\X\xa8\xf2\x047}\xc1\xdfK\xb0\x1aF\xa8i*\'\x92\xf7\xf4")) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HOGAN', 'weight': 66, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50606, 'height': 6.8, 'child1_name': 'Josephine', 'no_of_violatn': 2, 'no_of_child': 1, 'city': nan, 'first_name': 'Suhaila', 'gender_x': 'F', 'credit_rating': 596, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-02-19 00:00:00'), 'state': 'New Jersey', 'date_of_birth': Timestamp('1990-12-19 00:00:00'), 'ssn_no': '38-38-3880', 'model_id': 'M00062', 'license_susp': 'No', 'vin': '3GYFNBE34FS595795', 'spouse_d_o_b': Timestamp('1992-12-19 00:00:00'), 'cust_id': 3200465361, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1990-12-19 00:00:00'), 'country': 'USA', 'age': 26, 'vehicle_no': 69452, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLE', 'payment_type': 'Lease', 'strt_address': '633 Stag Trail Road in North Caldwell'}
# ('dev', 'customer_data', None, bytearray(b'\xce\xfcr\xf9\x16N\xf3\x13!\xf3@;I\xc1\x908b\x91Ha')) {'child2_d_o_b': nan, 'spouse_name': 'Arden', 'last_name': 'COOKE', 'weight': 55, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 50514, 'height': 4.4, 'child1_name': nan, 'no_of_violatn': 1, 'no_of_child': 0, 'city': 'New York', 'first_name': 'Croy', 'gender_x': 'M', 'credit_rating': 535, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1980-08-30 00:00:00'), 'ssn_no': '82-82-2058', 'model_id': 'M00011', 'license_susp': 'No', 'vin': 'WDBRF40J35A783885', 'spouse_d_o_b': Timestamp('1978-08-30 00:00:00'), 'cust_id': 1176389539, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1980-08-30 00:00:00'), 'country': 'USA', 'age': 36, 'vehicle_no': 65926, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '86th floor of "the skyscraper" (implicitly the Empire State Building)'}
# ('dev', 'customer_data', None, bytearray(b'`\x8aN\x1aU\xe7\xef0\x1ewJm\xee\x00\x07J\xb9\x95\x88\xbd')) {'child2_d_o_b': nan, 'spouse_name': 'Bridget', 'last_name': 'OROZCO', 'weight': 93, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 51331, 'height': 6.4, 'child1_name': 'Mattie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Beauford', 'gender_x': 'M', 'credit_rating': 763, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-01-29 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1995-11-08 00:00:00'), 'ssn_no': '27-27-8903', 'model_id': 'M00036', 'license_susp': 'No', 'vin': '1N4AL3AP2DC235700', 'spouse_d_o_b': Timestamp('1993-11-08 00:00:00'), 'cust_id': 8782507386, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1995-11-08 00:00:00'), 'country': 'USA', 'age': 21, 'vehicle_no': 80770, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CS', 'payment_type': 'Buy', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'T\x18tT\x90b\xcd\xc7\xd74\xfbm\xc5xqQ\xde\xc0zK')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'LANDRY', 'weight': 68, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 51431, 'height': 4.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': nan, 'first_name': 'Amarea', 'gender_x': 'F', 'credit_rating': 612, 'marital_sts': 'Widowed', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1966-04-08 00:00:00'), 'ssn_no': '87-87-4380', 'model_id': 'M00063', 'license_susp': 'No', 'vin': nan, 'spouse_d_o_b': Timestamp('1968-04-08 00:00:00'), 'cust_id': 3756541463, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1966-04-08 00:00:00'), 'country': 'USA', 'age': 50, 'vehicle_no': 59700, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CSLC', 'payment_type': 'Buy', 'strt_address': '2354 Pacific Coast Highway'}
# ('dev', 'customer_data', None, bytearray(b'Jb\xbas\xb2<\r\x17\x1fnf\x9b\x91\xd7\xf2q\xde\xcc\xf2a')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'SCHWARTZ', 'weight': 83, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 52002, 'height': 4.5, 'child1_name': 'Maggie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': nan, 'first_name': 'Anais', 'gender_x': 'F', 'credit_rating': 698, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-02-15 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1995-03-25 00:00:00'), 'ssn_no': '64-64-6954', 'model_id': 'M00057', 'license_susp': 'No', 'vin': '1FDXE45F83HB93438', 'spouse_d_o_b': Timestamp('1997-03-25 00:00:00'), 'cust_id': 6617387789, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1995-03-25 00:00:00'), 'country': 'USA', 'age': 22, 'vehicle_no': 78567, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLE', 'payment_type': 'Buy', 'strt_address': 'Cemetery Ridge, USA'}
# ('dev', 'customer_data', None, bytearray(b'\xb91m\xb6\x99(#\x17z\x8du\xcc\xc1S+9\x8d99a')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HARRIS', 'weight': 60, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 51232, 'height': 5.1, 'child1_name': 'Nettie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Vianka', 'gender_x': 'F', 'credit_rating': 562, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-03-06 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1990-03-13 00:00:00'), 'ssn_no': '15-15-2884', 'model_id': 'M00081', 'license_susp': 'No', 'vin': '5FNYF48549B036300', 'spouse_d_o_b': Timestamp('1992-03-13 00:00:00'), 'cust_id': 2094139645, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1990-03-13 00:00:00'), 'country': 'USA', 'age': 27, 'vehicle_no': 86574, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '86th floor of "the skyscraper" (implicitly the Empire State Building)'}
# ('dev', 'customer_data', None, bytearray(b'\xd0\xe5\xa2\x1a\xc8\x95\xf3}*t\x1eF\xcc\x83\xb2:\xba\xfe\xd5\x9f')) {'child2_d_o_b': nan, 'spouse_name': 'Ivanna', 'last_name': 'TRAN', 'weight': 94, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 51432, 'height': 5.8, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Brooklyn', 'first_name': 'Santana', 'gender_x': 'M', 'credit_rating': 769, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1962-06-17 00:00:00'), 'ssn_no': '60-60-9092', 'model_id': 'M00021', 'license_susp': 'No', 'vin': 'P855H8029', 'spouse_d_o_b': Timestamp('1960-06-17 00:00:00'), 'cust_id': 8992995570, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Gynecologist', 'dob': Timestamp('1962-06-17 00:00:00'), 'country': 'USA', 'age': 54, 'vehicle_no': 76684, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CE', 'payment_type': 'Lease', 'strt_address': '10 Stigwood Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\x04B\xfb\xc7\x9e\x11\x8e\x17\xd8\xd78\x10\x82\x9f\xbc\x03*\x84\x96\xa9')) {'child2_d_o_b': nan, 'spouse_name': 'Maeve', 'last_name': 'ARMSTRONG', 'weight': 64, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 52720, 'height': 6.0, 'child1_name': 'Susan', 'no_of_violatn': 1, 'no_of_child': 1, 'city': 'Hollywood', 'first_name': 'Alvis', 'gender_x': 'M', 'credit_rating': 585, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-03-21 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1976-08-04 00:00:00'), 'ssn_no': '44-44-3573', 'model_id': 'M00099', 'license_susp': 'No', 'vin': '1HGCM56306A057853', 'spouse_d_o_b': Timestamp('1974-08-04 00:00:00'), 'cust_id': 2860271122, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Professor', 'dob': Timestamp('1976-08-04 00:00:00'), 'country': 'USA', 'age': 40, 'vehicle_no': 60920, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CE', 'payment_type': 'Buy', 'strt_address': '8411 1/2 Sunset Boulevard'}
# ...
# ('dev', 'customer_data', None, bytearray(b'\x9c}\xf4[\xd8\x14\x08\t\x99\x8a(\x8c\x8d\xba\xc2e\x16Zi\xaa')) {'child2_d_o_b': nan, 'spouse_name': 'Frankie', 'last_name': 'RIGGS', 'weight': 70, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 50033, 'height': 7.0, 'child1_name': 'Florence', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Dvante', 'gender_x': 'M', 'credit_rating': 620, 'marital_sts': 'Divorced', 'child1_d_o_b': Timestamp('1950-01-14 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1977-03-27 00:00:00'), 'ssn_no': '37-37-4617', 'model_id': 'M00017', 'license_susp': 'No', 'vin': '2FMDK4KC1ABA19940', 'spouse_d_o_b': Timestamp('1975-03-27 00:00:00'), 'cust_id': 4020344733, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2009-09-09 00:00:00'), 'designation': 'Administrator', 'dob': Timestamp('1977-03-27 00:00:00'), 'country': 'USA', 'age': 40, 'vehicle_no': 64968, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CE', 'payment_type': 'Lease', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'Of|\xf8\xbe?\xcb@L\xefR\x16\xda\xbax\xa1\xcd\xe8\xeb\xd6')) {'child2_d_o_b': nan, 'spouse_name': 'Zara', 'last_name': 'COFFEY', 'weight': 82, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 52535, 'height': 6.4, 'child1_name': 'Blanche', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Doy', 'gender_x': 'M', 'credit_rating': 694, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-02-28 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1990-12-30 00:00:00'), 'ssn_no': '78-78-6840', 'model_id': 'M00073', 'license_susp': 'No', 'vin': 'F10YCR23997', 'spouse_d_o_b': Timestamp('1988-12-30 00:00:00'), 'cust_id': 6490479961, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2012-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1990-12-30 00:00:00'), 'country': 'USA', 'age': 26, 'vehicle_no': 63968, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CG', 'payment_type': 'Lease', 'strt_address': '454 West 35th Street'}
# ('dev', 'customer_data', None, bytearray(b':\x9c\xa5r*\x82\x99y\x00#=>\x80\xe6;\xb4\xdd\xa611')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BAIRD', 'weight': 54, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50034, 'height': 6.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Camden', 'first_name': 'Vaneka', 'gender_x': 'F', 'credit_rating': 528, 'marital_sts': 'Single', 'child1_d_o_b': NaT, 'state': nan, 'date_of_birth': Timestamp('1958-01-21 00:00:00'), 'ssn_no': '63-63-1861', 'model_id': 'M00095', 'license_susp': 'No', 'vin': 'ARJ01769B494', 'spouse_d_o_b': Timestamp('1960-01-21 00:00:00'), 'cust_id': 956851195, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2006-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1958-01-21 00:00:00'), 'country': 'USA', 'age': 59, 'vehicle_no': 68056, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CE', 'payment_type': 'Lease', 'strt_address': '9005 Lincoln Blvd'}
# ('dev', 'customer_data', None, bytearray(b'\xc2\xef\x0e\xa3\xccB\x9f\xdb:\xb5\x97\xc9\xff\x99\xdb\xf9\xf2)<\xf6')) {'child2_d_o_b': nan, 'spouse_name': 'Elena', 'last_name': 'RAMIREZ', 'weight': 66, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 52209, 'height': 6.3, 'child1_name': 'Marie', 'no_of_violatn': 4, 'no_of_child': 2, 'city': 'Hill Valley', 'first_name': 'Joshawn', 'gender_x': 'M', 'credit_rating': 598, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-02-24 00:00:00'), 'state': 'California', 'date_of_birth': Timestamp('1981-04-25 00:00:00'), 'ssn_no': '17-17-3954', 'model_id': 'M00068', 'license_susp': 'No', 'vin': 'JN1CA21D9ST056384', 'spouse_d_o_b': Timestamp('1979-04-25 00:00:00'), 'cust_id': 3283505055, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2008-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1981-04-25 00:00:00'), 'country': 'USA', 'age': 35, 'vehicle_no': 63676, 'child2_name': 'Marie', 'eye_and_hair': 'Blue', 'class_id': 'CSL', 'payment_type': 'Buy', 'strt_address': '1640 Riverside Drive'}
# ('dev', 'customer_data', None, bytearray(b'(\x14z\xda /\xde`@\xd66.|\xa6\xec\xbc@\x9d\xc3\xfd')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'AUSTIN', 'weight': 96, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 52536, 'height': 6.9, 'child1_name': 'Josephine', 'no_of_violatn': 2, 'no_of_child': 1, 'city': 'Cypress Creek', 'first_name': 'Jacolyn', 'gender_x': 'F', 'credit_rating': 779, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2009-11-20 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1980-11-20 00:00:00'), 'ssn_no': '23-23-9395', 'model_id': 'M00050', 'license_susp': 'No', 'vin': 'JTJGW31U972001837', 'spouse_d_o_b': Timestamp('1982-11-20 00:00:00'), 'cust_id': 9329017447, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1980-11-20 00:00:00'), 'country': 'USA', 'age': 36, 'vehicle_no': 80799, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLC', 'payment_type': 'Buy', 'strt_address': '15201 Maple Systems Road'}
# ('dev', 'customer_data', None, bytearray(b'-\xcd\xbb\xa1\xa2_a\x9b+\xef\x86\xfa\x97#V\x83f\xd5*\xf2')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'MAYS', 'weight': 99, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 51630, 'height': 5.2, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Salem Center', 'first_name': 'Marles', 'gender_x': 'F', 'credit_rating': 798, 'marital_sts': 'Married', 'child1_d_o_b': NaT, 'state': 'New York', 'date_of_birth': Timestamp('1981-07-29 00:00:00'), 'ssn_no': nan, 'model_id': 'M00051', 'license_susp': 'No', 'vin': 'JS2YB5A37A6310041', 'spouse_d_o_b': Timestamp('1983-07-29 00:00:00'), 'cust_id': 9963407164, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1981-07-29 00:00:00'), 'country': 'USA', 'age': 35, 'vehicle_no': 66585, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLC', 'payment_type': 'Buy', 'strt_address': '1407 Graymalkin Lane'}
# ('dev', 'customer_data', None, bytearray(b'\xb5:\x08\x8c\x84\xa8\xa3e\n\xa8\r;S\x15\xae\xf3t\x82\xeb"')) {'child2_d_o_b': nan, 'spouse_name': 'Amaris', 'last_name': 'MCLEAN', 'weight': 76, 'gender_y': 'M', 'job_type': 'Professional', 'pincode': 51523, 'height': 6.0, 'child1_name': 'Gertrude', 'no_of_violatn': 1, 'no_of_child': 1, 'city': 'Brooklyn', 'first_name': 'Auburn', 'gender_x': 'M', 'credit_rating': 658, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('1981-11-17 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1952-11-17 00:00:00'), 'ssn_no': '45-45-5754', 'model_id': 'M00025', 'license_susp': 'No', 'vin': '1N4DL01D9WC221703', 'spouse_d_o_b': Timestamp('1950-11-17 00:00:00'), 'cust_id': 5283226484, 'no_of_accidnt': 1, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Neurologist', 'dob': Timestamp('1952-11-17 00:00:00'), 'country': 'USA', 'age': 64, 'vehicle_no': 81355, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CS', 'payment_type': 'Lease', 'strt_address': '10 Stigwood Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\x9f\x98\xe3^\xd3\xfaY\xb7\x0e\x13\xda\xc2\x98\xbeeS$\xd5\xd7\x01')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HOUSTON', 'weight': 73, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50836, 'height': 5.2, 'child1_name': 'Hattie', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Kejuana', 'gender_x': 'F', 'credit_rating': 640, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-01-27 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1972-01-02 00:00:00'), 'ssn_no': '31-31-5221', 'model_id': 'M00033', 'license_susp': 'No', 'vin': '1FMZU73E34UB70892', 'spouse_d_o_b': Timestamp('1974-01-02 00:00:00'), 'cust_id': 4691335523, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2010-09-09 00:00:00'), 'designation': 'Cardiologist', 'dob': Timestamp('1972-01-02 00:00:00'), 'country': 'USA', 'age': 45, 'vehicle_no': 62612, 'child2_name': nan, 'eye_and_hair': 'Blue', 'class_id': 'CS', 'payment_type': 'Lease', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'\xf3\xe10\x1a\x0e\x0c#\xba\xcd\x1a\xea\xd7\xeb\xbf\xd71i\xf0vX')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GAY', 'weight': 75, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 52537, 'height': 4.4, 'child1_name': nan, 'no_of_violatn': 0, 'no_of_child': 0, 'city': 'Vista', 'first_name': 'Johnna', 'gender_x': 'F', 'credit_rating': 653, 'marital_sts': 'Separated', 'child1_d_o_b': NaT, 'state': 'California', 'date_of_birth': Timestamp('1992-06-05 00:00:00'), 'ssn_no': '34-34-5612', 'model_id': 'M00069', 'license_susp': 'No', 'vin': '4T1BD1FK8EU122581', 'spouse_d_o_b': Timestamp('1994-06-05 00:00:00'), 'cust_id': 5125407632, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Anesthesiologist', 'dob': Timestamp('1992-06-05 00:00:00'), 'country': 'USA', 'age': 24, 'vehicle_no': 60028, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLS', 'payment_type': 'Lease', 'strt_address': '834 Ocean Vista Avenue #201'}
# ('dev', 'customer_data', None, bytearray(b"\x01\x9e\x15\x18\x94\xce.\'\x9dAT\x8f\xef\xd1\x07\x96\xcd\xdeR-")) {'child2_d_o_b': nan, 'spouse_name': 'Veda', 'last_name': 'MEYER', 'weight': 98, 'gender_y': 'M', 'job_type': 'Business', 'pincode': 52726, 'height': 5.8, 'child1_name': 'Ada', 'no_of_violatn': 5, 'no_of_child': 1, 'city': 'Springfield', 'first_name': 'Cliffton', 'gender_x': 'M', 'credit_rating': 788, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-02 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1960-07-25 00:00:00'), 'ssn_no': '90-90-9643', 'model_id': 'M00041', 'license_susp': 'Yes', 'vin': '1FADP3F29EL434999', 'spouse_d_o_b': Timestamp('1958-07-25 00:00:00'), 'cust_id': 9605404937, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2016-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1960-07-25 00:00:00'), 'country': 'USA', 'age': 56, 'vehicle_no': 86881, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CCLA', 'payment_type': 'Buy', 'strt_address': '742 Evergreen Terrace,'}
# ('dev', 'customer_data', None, bytearray(b'E!EK\xf2c/O2X\xac\xc8\x86 \xa5|\xf2W\xf5\xe3')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'BARTON', 'weight': 62, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50519, 'height': 5.9, 'child1_name': 'Myrtle', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'New York', 'first_name': 'Tyquesha', 'gender_x': 'F', 'credit_rating': 573, 'marital_sts': 'Separated', 'child1_d_o_b': Timestamp('1950-02-09 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1983-04-27 00:00:00'), 'ssn_no': '57-57-3196', 'model_id': 'M00049', 'license_susp': 'No', 'vin': '1HGCR2F36FA160565', 'spouse_d_o_b': Timestamp('1985-04-27 00:00:00'), 'cust_id': 2440506506, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1983-04-27 00:00:00'), 'country': 'USA', 'age': 33, 'vehicle_no': 71188, 'child2_name': nan, 'eye_and_hair': 'Black', 'class_id': 'CGLA', 'payment_type': 'Buy', 'strt_address': '8 Remsen Drive, Brooklyn Heights'}
# ('dev', 'customer_data', None, bytearray(b'p\xceWR\xafLc#\x1b\x13\xbbJ=\x91d\x8eU\x1d\x81\xb6')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'CONTRERAS', 'weight': 95, 'gender_y': 'F', 'job_type': 'Professional', 'pincode': 50448, 'height': 6.7, 'child1_name': 'Edna', 'no_of_violatn': 4, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Mercedes', 'gender_x': 'F', 'credit_rating': 773, 'marital_sts': 'Married', 'child1_d_o_b': Timestamp('1950-02-14 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1965-05-29 00:00:00'), 'ssn_no': '45-45-9200', 'model_id': 'M00056', 'license_susp': 'No', 'vin': '2B4GP44G7YR596036', 'spouse_d_o_b': Timestamp('1967-05-29 00:00:00'), 'cust_id': 9112386251, 'no_of_accidnt': 2, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'Research Scientist', 'dob': Timestamp('1965-05-29 00:00:00'), 'country': 'USA', 'age': 51, 'vehicle_no': 61537, 'child2_name': 'Edna', 'eye_and_hair': 'Brown', 'class_id': 'CGLE', 'payment_type': 'Buy', 'strt_address': '185 West 74th Street'}
# ('dev', 'customer_data', None, bytearray(b'\x96\xe9\x10\xac]\xe0\xa6\xfb\xc9`\x9c\x00\x1b7\n\x12rgf\x80')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'GOODWIN', 'weight': 94, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 52620, 'height': 4.6, 'child1_name': 'Belle', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'New York', 'first_name': 'Lanore', 'gender_x': 'F', 'credit_rating': 767, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('2026-01-02 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1997-01-02 00:00:00'), 'ssn_no': '79-79-9034', 'model_id': 'M00090', 'license_susp': 'No', 'vin': 'SALTY12412A766109', 'spouse_d_o_b': Timestamp('1999-01-02 00:00:00'), 'cust_id': 8928475822, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2015-09-09 00:00:00'), 'designation': 'CEO', 'dob': Timestamp('1997-01-02 00:00:00'), 'country': 'USA', 'age': 20, 'vehicle_no': 77300, 'child2_name': 'Belle', 'eye_and_hair': 'Blue', 'class_id': 'CC', 'payment_type': 'Lease', 'strt_address': '1049 Park Avenue'}
# ('dev', 'customer_data', None, bytearray(b'\xf4\x87\xe4\x8e\x14\xa9u\xeb\xa3\xc1\xb70\x9b{\x9a\xbc3\xaa\x006')) {'child2_d_o_b': nan, 'spouse_name': nan, 'last_name': 'HANCOCK', 'weight': 77, 'gender_y': 'F', 'job_type': 'Business', 'pincode': 50009, 'height': 5.3, 'child1_name': 'Kate', 'no_of_violatn': 0, 'no_of_child': 1, 'city': 'Springfield', 'first_name': 'Dashia', 'gender_x': 'F', 'credit_rating': 665, 'marital_sts': 'Widowed', 'child1_d_o_b': Timestamp('1950-03-20 00:00:00'), 'state': nan, 'date_of_birth': Timestamp('1994-01-04 00:00:00'), 'ssn_no': '55-55-5962', 'model_id': 'M00098', 'license_susp': 'No', 'vin': '5N1AR1NB8BC625561', 'spouse_d_o_b': Timestamp('1996-01-04 00:00:00'), 'cust_id': 5514367304, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2011-09-09 00:00:00'), 'designation': 'Managing Director', 'dob': Timestamp('1994-01-04 00:00:00'), 'country': 'USA', 'age': 23, 'vehicle_no': 60448, 'child2_name': nan, 'eye_and_hair': 'Brown', 'class_id': 'CE', 'payment_type': 'Lease', 'strt_address': '742 Evergreen Terrace'}
# ('dev', 'customer_data', None, bytearray(b's\'$\xdc\x99\x1fo\x01\x94\xea\xcc\xed\xc5w$\x9c+\xed\x05"')) {'child2_d_o_b': nan, 'spouse_name': 'Aubree', 'last_name': 'WILCOX', 'weight': 61, 'gender_y': 'M', 'job_type': 'Government', 'pincode': 50036, 'height': 4.5, 'child1_name': 'Eliza', 'no_of_violatn': 0, 'no_of_child': 2, 'city': 'Hydsberg', 'first_name': 'Monroe', 'gender_x': 'M', 'credit_rating': 569, 'marital_sts': 'Single', 'child1_d_o_b': Timestamp('1985-09-08 00:00:00'), 'state': 'New York', 'date_of_birth': Timestamp('1956-09-08 00:00:00'), 'ssn_no': '26-26-3070', 'model_id': 'M00085', 'license_susp': 'No', 'vin': 'JN8AS5MV8BW261334', 'spouse_d_o_b': Timestamp('1954-09-08 00:00:00'), 'cust_id': 2300372819, 'no_of_accidnt': 0, 'dt_of_purchse': Timestamp('2007-09-09 00:00:00'), 'designation': 'Major general', 'dob': Timestamp('1956-09-08 00:00:00'), 'country': 'USA', 'age': 60, 'vehicle_no': 59166, 'child2_name': 'Eliza', 'eye_and_hair': 'Brown', 'class_id': 'CC', 'payment_type': 'Buy', 'strt_address': '123 Marshall Road'}

# %% [markdown]
# ### Create index for table dev.customer_data
#
# Syntax - CREATE INDEX numindex ON test.testset (binB) NUMERIC|STRING
#
# ###### Index 'cust_id'
# create index i_cust_id on dev.customer_data (cust_id) numeric
