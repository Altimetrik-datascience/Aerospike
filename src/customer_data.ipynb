# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
Prepare consolidated data

"""

# Import libraries

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import pandas as pd
import aerospike
import json

print(__doc__)

class Consolidate:
    
    def __init__(self):
        pass
        
    def read(self, file):
        data = pd.read_excel(file)
        return data

    def clean_data(self, data):
    
        # Select numeric data alone from data object
        numeric_data = data.loc[:, data.dtypes != object]
    
        # Select string data alone from data object to trim
        trim_data = data.select_dtypes(['object'])
    
        # Trim all string objects
        trim_data = trim_data.apply(lambda x: x.str.strip())
    
        # Merge numeric and string data in to data object
        data = pd.concat([numeric_data, trim_data], axis=1)
    
        # Change column name to lower case
        data.columns = [x.lower() for x in data.columns]
        return data
    
    def load_data(self, data):
            
        # Split dataframe into key and records
        key = data['cust_id']
    
        record_json = data.to_dict(orient='records')
    
        config = {
            'hosts': [ ('127.0.0.1', 3000) ]
        }

        # Create a client and connect it to the cluster
        try:
            client = aerospike.client(config).connect()
        except:
            import sys
            print("failed to connect to the cluster with", config['hosts'])
            sys.exit(1)
    
        # Records are addressable via a tuple of (namespace, set, key)
        for pk, bin in zip(key, record_json):
            string = "('dev', 's1bd', "
            string +=`pk`
            string = string + ")"
        
            from ast import literal_eval as make_tuple
            string = make_tuple(string)
        
            try:
                client = aerospike.client(config).connect()
                # Write a record
                client.put(string, bin)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)

            # Read a record after insert for verification
            (key, metadata, record) = client.get(string)
            print (key, record)
        
            # Close the connection to the Aerospike cluster
            client.close()
    
    def remove_data(self, data):

        key = data['cust_id']
    
        config = {
          'hosts': [ ('127.0.0.1', 3000) ]
        }

        # Create a client and connect it to the cluster
        try:
            client = aerospike.client(config).connect()
        except:
            import sys
            print("failed to connect to the cluster with", config['hosts'])
            sys.exit(1)
    
        # Records are addressable via a tuple of (namespace, set, key)
        for pk in key:
            string = "('dev', 's1bd', "
            string +=`pk`
            string = string + ")"
        
            from ast import literal_eval as make_tuple
            string = make_tuple(string)
        
            try:
                client = aerospike.client(config).connect()
                # Remove a record
                client.remove(string)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)

            # Close the connection to the Aerospike cluster
            client.close()
    
def drive(mode):
    
    cons = Consolidate()

    # Read customer details excel
    data1 = cons.read("/home/azureuser/Aerospike/data/customer/customer details.xls")
    
    # Clean data1
    data1 = cons.clean_data(data1)
    #print (data1.columns)
    
    # Read Customer vehicle excel
    data2 = cons.read("/home/azureuser/Aerospike/data/customer/Customer_vehicle.xls")
    
    # Clean data2
    data2 = cons.clean_data(data2)
    #print (data2.columns)
    
    # Merge data1 and data2 by cust_id
    data2 = pd.merge(data1, data2, on='cust_id', how='inner')
    
    # Read Motor vehicle report excel
    data3 = cons.read("/home/azureuser/Aerospike/data/customer/Motor_vehicle_report.xls")
    
    # Clean data3
    data3 = cons.clean_data(data3)
    
    # Merge data2 and data3 by vehicle_no
    data3 = pd.merge(data2, data3, on='vehicle_no', how='inner')
    #print (data3.columns)
    
    # Read Customer address excel
    data4 = cons.read("/home/azureuser/Aerospike/data/customer/customer_address.xls")
    
    # Clean data4
    data4 = cons.clean_data(data4)
    
    # Merge data3 and data4 by cust_id
    data4 = pd.merge(data3, data4, on='cust_id', how='inner')
    #print (data4.columns)
    print (data4.count)
    
    if mode == 'load':
        # Load data in to aerospike
        cons.load_data(data4)
    else:
        # Remove data from aerospike
        cons.remove_data(data4)
    
if __name__ == '__main__':
    drive('delete')
# Out:
# Prepare consolidated data
#
#
# <bound method DataFrame.count of        cust_id        dob  no_of_child child1_d_o_b  credit_rating  \
# 0   2396305636 1982-10-21            1   1950-02-01            571
# 1     84711641 1988-02-07            1   1950-01-10            502
# 2   1561684799 1994-02-22            1   1950-02-26            546
# 3   9006719754 1987-05-07            1   1950-01-28            770
# 4   3947774146 1970-05-20            0          NaT            618
# 5   2006085121 1963-12-05            2   1950-01-25            560
# 6   1907459679 1954-04-26            1   1950-02-27            557
# 7   2398850356 1995-02-11            0          NaT            571
# 8   8486613847 1992-10-06            2   2021-10-06            754
# 9   4195354888 1953-08-05            2   1950-03-14            625
# 10  8833668145 1990-12-16            0          NaT            765
# 11  2093269256 1989-06-22            0          NaT            562
# 12  4927435058 1988-01-03            1   2017-01-03            647
# 13   242339097 1972-07-07            1   1950-01-02            507
# 14  6412160291 1972-07-01            1   1950-03-03            692
# 15  3583260108 1965-03-19            0          NaT            607
# 16  2009007839 1962-05-06            2   1950-02-06            560
# 17  8126984299 1970-01-08            1   1950-01-30            743
# 18  3010547079 1987-10-21            2   1950-01-12            590
# 19  3715310229 1981-08-15            0          NaT            611
# 20  8529245634 1986-08-22            1   2015-08-22            755
# 21  8969745570 1976-05-03            2   1950-02-13            769
# 22  3951047982 1980-08-30            0          NaT            618
# 23  1340761503 1988-07-24            1   1950-01-05            540
# 24  2071190194 1983-02-19            1   1950-01-03            562
# 25  1804203393 1950-04-03            0          NaT            554
# 26  1213351171 1959-01-23            2   1950-03-02            536
# 27  9601344591 1965-06-15            0          NaT            788
# 28  6784656776 1969-05-17            0          NaT            703
# 29  6441436193 1985-10-26            1   1950-02-17            693
# ..         ...        ...          ...          ...            ...
# 70  1434949636 1999-04-07            1   2028-04-07            543
# 71  3906577897 1990-06-01            2   1950-01-06            617
# 72  1788688153 1971-02-17            2   1950-02-05            553
# 73   682216554 1981-07-19            0          NaT            520
# 74  5371957344 1957-02-28            2   1950-03-05            661
# 75  7550054702 1996-07-07            0          NaT            726
# 76  2157335495 1969-08-01            0          NaT            564
# 77  2216013972 1976-12-19            2   1950-01-01            566
# 78  7275477859 1953-03-07            1   1950-03-18            718
# 79  9419697469 1980-06-17            1   1950-01-31            782
# 80  7213476474 1983-01-06            2   1950-02-03            716
# 81  9985948894 1963-03-25            1   1950-03-04            799
# 82  8349364525 1977-03-07            1   1950-03-01            750
# 83  7485557938 1981-11-29            1   1950-02-16            724
# 84  5363044179 1975-02-04            0          NaT            660
# 85  4020344733 1977-03-27            1   1950-01-14            620
# 86  6490479961 1990-12-30            1   1950-02-28            694
# 87   956851195 1958-01-21            0          NaT            528
# 88  3283505055 1981-04-25            2   1950-02-24            598
# 89  9329017447 1980-11-20            1   2009-11-20            779
# 90  9963407164 1981-07-29            0          NaT            798
# 91  5283226484 1952-11-17            1   1981-11-17            658
# 92  4691335523 1972-01-02            1   1950-01-27            640
# 93  5125407632 1992-06-05            0          NaT            653
# 94  9605404937 1960-07-25            1   1950-02-02            788
# 95  2440506506 1983-04-27            1   1950-02-09            573
# 96  9112386251 1965-05-29            2   1950-02-14            773
# 97  8928475822 1997-01-02            2   2026-01-02            767
# 98  5514367304 1994-01-04            1   1950-03-20            665
# 99  2300372819 1956-09-08            2   1985-09-08            569
#
#    spouse_d_o_b first_name  last_name gender_x         designation   ...    \
# 0    1984-10-21   Quatasia       LOWE        F                 CTO   ...
# 1    1986-02-07       Elia      CROSS        M                 CEO   ...
# 2    1992-02-22      Mardy     MONTES        M              Doctor   ...
# 3    1985-05-07  Elisandro       TODD        M        Cardiologist   ...
# 4    1972-05-20    Lyndell    PARSONS        F    Anesthesiologist   ...
# 5    1965-12-05      Retta      LUCAS        F                 CFO   ...
# 6    1952-04-26        Lue       CHOI        M           Professor   ...
# 7    1993-02-11      Nolan     SPENCE        M     Chief Architect   ...
# 8    1990-10-06     Erasmo     SPEARS        M                 CEO   ...
# 9    1951-08-05     Leslie     HANSON        M   Managing Director   ...
# 10   1988-12-16       Flor      OLSON        M         Neurologist   ...
# 11   1991-06-22     Paulla       SIMS        F                 CEO   ...
# 12   1990-01-03     Jovita    FLOWERS        F                 CEO   ...
# 13   1970-07-07     Shloma         LE        M                 CEO   ...
# 14   1974-07-01   Graciana   BRADFORD        F                 CEO   ...
# 15   1963-03-19   Thornton     FRANCO        M                 CEO   ...
# 16   1964-05-06     Sidney   HARRISON        F        Gynecologist   ...
# 17   1972-01-08   Charnell      OWENS        F           Professor   ...
# 18   1989-10-21     Dannie      MOORE        F       Administrator   ...
# 19   1979-08-15     Lugene      HOBBS        M                 CEO   ...
# 20   1988-08-22    Luberta       MORA        F   Managing Director   ...
# 21   1978-05-03     Jeanny     FOSTER        F         Neurologist   ...
# 22   1978-08-30       Jere    ROLLINS        M                 CEO   ...
# 23   1990-07-24      Valta     GRAVES        F         Neurologist   ...
# 24   1985-02-19     Maggie   CAMPBELL        F                 CEO   ...
# 25   1952-04-03     Carole    ANDREWS        F        Pediatrician   ...
# 26   1957-01-23     Junuis      WELCH        M                 CEO   ...
# 27   1967-06-15    Shamora      BAIRD        F                 CEO   ...
# 28   1967-05-17       Robi     HOOVER        M                 CFO   ...
# 29   1983-10-26      Ellis    MAXWELL        M                 CEO   ...
# ..          ...        ...        ...      ...                 ...   ...
# 70   2001-04-07     Linnea      KIRBY        F        Cardiologist   ...
# 71   1988-06-01     Lander  MALDONADO        M    Anesthesiologist   ...
# 72   1973-02-17    Alverta   BARTLETT        F                 CFO   ...
# 73   1979-07-19       Eben      WATTS        M           Professor   ...
# 74   1955-02-28    Frankie    NAVARRO        M       Administrator   ...
# 75   1998-07-07   Allianna    GREGORY        F                 CEO   ...
# 76   1971-08-01       Merl   BROWNING        F   Managing Director   ...
# 77   1978-12-19      Patsy    PARRISH        F         Neurologist   ...
# 78   1951-03-07      Susan       WOLF        M                 CEO   ...
# 79   1982-06-17      Desta    SANTANA        F                 CEO   ...
# 80   1981-01-06     Dallas    FISCHER        M                 CEO   ...
# 81   1961-03-25    Raynold     HOWELL        M                 CEO   ...
# 82   1979-03-07    Nakhiya  GUTIERREZ        F                 CEO   ...
# 83   1979-11-29     Jarold      BATES        M        Gynecologist   ...
# 84   1977-02-04    Margree    DANIELS        F           Professor   ...
# 85   1975-03-27     Dvante      RIGGS        M       Administrator   ...
# 86   1988-12-30        Doy     COFFEY        M                 CEO   ...
# 87   1960-01-21     Vaneka      BAIRD        F   Managing Director   ...
# 88   1979-04-25    Joshawn    RAMIREZ        M         Neurologist   ...
# 89   1982-11-20    Jacolyn     AUSTIN        F   Managing Director   ...
# 90   1983-07-29     Marles       MAYS        F         Neurologist   ...
# 91   1950-11-17     Auburn     MCLEAN        M         Neurologist   ...
# 92   1974-01-02    Kejuana    HOUSTON        F        Cardiologist   ...
# 93   1994-06-05     Johnna        GAY        F    Anesthesiologist   ...
# 94   1958-07-25   Cliffton      MEYER        M                 CEO   ...
# 95   1985-04-27   Tyquesha     BARTON        F   Managing Director   ...
# 96   1967-05-29   Mercedes  CONTRERAS        F  Research Scientist   ...
# 97   1999-01-02     Lanore    GOODWIN        F                 CEO   ...
# 98   1996-01-04     Dashia    HANCOCK        F   Managing Director   ...
# 99   1954-09-08     Monroe     WILCOX        M       Major general   ...
#
#    no_of_violatn no_of_accidnt gender_y eye_and_hair license_susp  pincode  \
# 0              0             0        F        Black           No    52531
# 1              0             0        M        Black           No    50001
# 2              3             1        M        Brown           No    50002
# 3              0             0        M        Brown           No    50003
# 4              0             0        F        Black           No    50830
# 5              0             0        F        Black           No    52530
# 6              0             0        M         Blue           No    52201
# 7              0             0        M         Blue           No    51001
# 8              0             0        M        Black           No    50510
# 9              6             2        M        Brown          Yes    52531
# 10             0             0        M         Blue           No    50005
# 11             0             0        F        Black           No    52202
# 12             0             0        F        Black           No    50006
# 13             1             1        M        Black           No    50420
# 14             0             0        F        Black           No    50511
# 15             2             1        M         Blue           No    50007
# 16             0             0        F        Brown           No    50008
# 17             4             2        F         Blue           No    50602
# 18             2             0        F        Black           No    51002
# 19             0             0        M         Blue           No    50603
# 20             2             1        F        Black           No    51003
# 21             0             0        F        Black           No    50009
# 22             6             0        M        Brown          Yes    52203
# 23             0             0        F        Black           No    52203
# 24             2             3        F        Brown           No    50010
# 25             0             0        F        Brown           No    52205
# 26             0             0        M        Brown           No    51652
# 27             0             0        F        Brown           No    52701
# 28             0             0        M        Brown           No    52030
# 29             3             1        M        Black           No    50020
# ..           ...           ...      ...          ...          ...      ...
# 70             0             0        F        Brown           No    50074
# 71             1             0        M         Blue           No    50609
# 72             0             0        F         Blue           No    50031
# 73             0             0        M        Black           No    52601
# 74             2             0        M         Blue           No    50833
# 75             0             0        F         Blue           No    52208
# 76             6             7        F        Black          Yes    52031
# 77             0             0        F        Brown           No    50421
# 78             0             0        M         Blue           No    52721
# 79             0             0        F         Blue           No    51559
# 80             0             0        M        Brown           No    50835
# 81             0             0        M         Blue           No    50220
# 82             0             0        F        Brown           No    52032
# 83             0             0        M         Blue           No    52403
# 84             0             0        F        Brown           No    52722
# 85             0             0        M        Black           No    50033
# 86             0             0        M         Blue           No    52535
# 87             0             0        F        Brown           No    50034
# 88             4             1        M         Blue           No    52209
# 89             2             1        F        Black           No    52536
# 90             0             0        F        Black           No    51630
# 91             1             1        M        Black           No    51523
# 92             0             0        F         Blue           No    50836
# 93             0             0        F        Black           No    52537
# 94             5             2        M        Black          Yes    52726
# 95             0             0        F        Black           No    50519
# 96             4             2        F        Brown           No    50448
# 97             0             0        F         Blue           No    52620
# 98             0             0        F        Brown           No    50009
# 99             0             0        M        Brown           No    50036
#
#                                          strt_address           city  \
# 0                                  715 Calhoun Street        Chicago
# 1                                     21 Jumbo Street            NaN
# 2                           8411 1/2 Sunset Boulevard      Hollywood
# 3                         834 Ocean Vista Avenue #201   Santa Monica
# 4                                 25 West 68th Street       New York
# 5                                    4222 Clinton Way    Los Angeles
# 6                                    890 Fifth Avenue      Manhattan
# 7                            344 Clinton St., Apt. 3B     Metropolis
# 8                                    1049 Park Avenue       New York
# 9                                  711 Calhoun Street        Chicago
# 10                          8411 1/2 Sunset Boulevard      Hollywood
# 11                                  9005 Lincoln Blvd         Camden
# 12                              742 Evergreen Terrace    Springfield
# 13                        834 Ocean Vista Avenue #201   Santa Monica
# 14                           15201 Maple Systems Road  Cypress Creek
# 15                                   890 Fifth Avenue      Manhattan
# 16                                  123 Marshall Road       Hydsberg
# 17                           15201 Maple Systems Road  Cypress Creek
# 18                               1407 Graymalkin Lane   Salem Center
# 19                                803 N. Dutton Drive            NaN
# 20                               3223 Aberdeen Avenue      Rego Park
# 21                                  9005 Lincoln Blvd         Camden
# 22                                  9055 Lincoln Blvd         Camden
# 23                                  9005 Lincoln Blvd         Camden
# 24                                  704 Hauser Street  New York City
# 25                                   4222 Clinton Way    Los Angeles
# 26                                25 West 68th Street       New York
# 27                               3223 Aberdeen Avenue      Rego Park
# 28                                   1000 Mammon Lane    Springfield
# 29                                   890 Fifth Avenue      Manhattan
# ..                                                ...            ...
# 70              Pimmit Hills Trailer Park, Space C-13         Camden
# 71                          8411 1/2 Sunset Boulevard      Hollywood
# 72                        834 Ocean Vista Avenue #201   Santa Monica
# 73              Pimmit Hills Trailer Park, Space C-13         Camden
# 74                                  704 Hauser Street  New York City
# 75                         2354 Pacific Coast Highway            NaN
# 76                                25 West 68th Street       New York
# 77  86th floor of "the skyscraper" (implicitly the...       New York
# 78                                803 N. Dutton Drive            NaN
# 79  86th floor of "the skyscraper" (implicitly the...       New York
# 80                               1407 Graymalkin Lane   Salem Center
# 81                                   79 Wistful Vista            NaN
# 82                           15201 Maple Systems Road  Cypress Creek
# 83                                 711 Calhoun Street        Chicago
# 84                               1640 Riverside Drive    Hill Valley
# 85                               185 West 74th Street       New York
# 86                               454 West 35th Street       New York
# 87                                  9005 Lincoln Blvd         Camden
# 88                               1640 Riverside Drive    Hill Valley
# 89                           15201 Maple Systems Road  Cypress Creek
# 90                               1407 Graymalkin Lane   Salem Center
# 91                                 10 Stigwood Avenue       Brooklyn
# 92                               185 West 74th Street       New York
# 93                        834 Ocean Vista Avenue #201          Vista
# 94                             742 Evergreen Terrace,    Springfield
# 95                   8 Remsen Drive, Brooklyn Heights       New York
# 96                               185 West 74th Street       New York
# 97                                   1049 Park Avenue       New York
# 98                              742 Evergreen Terrace    Springfield
# 99                                  123 Marshall Road       Hydsberg
#
#             state country
# 0        Illinois     USA
# 1     Bluffington     USA
# 2      California     USA
# 3      California     USA
# 4        New York     USA
# 5      California     USA
# 6   New York City     USA
# 7             NaN     USA
# 8        New York     USA
# 9        Illinois     USA
# 10     California     USA
# 11            NaN     USA
# 12            NaN     USA
# 13     California     USA
# 14            NaN     USA
# 15  New York City     NaN
# 16       New York     NaN
# 17            NaN     USA
# 18       New York     USA
# 19     California     USA
# 20       New York     USA
# 21            NaN     USA
# 22            NaN     USA
# 23            NaN     USA
# 24       New York     USA
# 25     California     USA
# 26       New York     USA
# 27       New York     USA
# 28            NaN     USA
# 29  New York City     USA
# ..            ...     ...
# 70            NaN     USA
# 71     California     USA
# 72     California     USA
# 73            NaN     USA
# 74       New York     USA
# 75     California     USA
# 76       New York     USA
# 77       New York     USA
# 78     California     USA
# 79       New York     USA
# 80       New York     USA
# 81            NaN     USA
# 82            NaN     USA
# 83       Illinois     USA
# 84     California     USA
# 85       New York     USA
# 86       New York     USA
# 87            NaN     USA
# 88     California     USA
# 89            NaN     USA
# 90       New York     USA
# 91       New York     USA
# 92       New York     USA
# 93     California     USA
# 94            NaN     USA
# 95       New York     USA
# 96       New York     USA
# 97       New York     USA
# 98            NaN     USA
# 99       New York     USA
#
# [100 rows x 37 columns]>
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
# error: (2L, 'AEROSPIKE_ERR_RECORD_NOT_FOUND', 'src/main/client/remove.c', 110)
