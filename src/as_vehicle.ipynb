# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
Load and delete Vehicle data

"""

# Import libraries

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import pandas as pd
import aerospike
import json
import csv

print(__doc__)

def load(file, ns, sets):
    
    global rec
    rec = {}

    csvfile  = open(file, "rb")
    reader = csv.reader(csvfile)

    config = {
                'hosts': [ ('127.0.0.1', 3000) ]
            }

    # Create a client and connect it to the cluster
    try:
        client = aerospike.client(config).connect()
    except:
        import sys
        print("failed to connect to the cluster with", config['hosts'])
        sys.exit(1)
            
    rownum = 0
    for row in reader:
        # Save First Row with headers
        if rownum == 0:
            header = row
            header = [x.lower() for x in header]
        else:
            colnum = 0
            for col in row:
                # print (rownum,header[colnum],col)
                rec[header[colnum]] = col
                colnum += 1
        rownum += 1
        # print(rownum,rec)
        if rec:
            try:
                client = aerospike.client(config).connect()
                # Write a record
                client.put((ns, sets, str(rownum)), rec)
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)
        
            # Read a record after insert for verification
            (key, metadata, record) = client.get((ns, sets, str(rownum)))
            print (key, record)
        
            # Close the connection to the Aerospike cluster
            client.close()
        rec = {}

def delete(file, ns, sets):
    
    global rec
    rec = {}

    csvfile  = open(file, "rb")
    reader = csv.reader(csvfile)

    config = {
                'hosts': [ ('127.0.0.1', 3000) ]
            }

    # Create a client and connect it to the cluster
    try:
        client = aerospike.client(config).connect()
    except:
        import sys
        print("failed to connect to the cluster with", config['hosts'])
        sys.exit(1)
            
    rownum = 0
    for row in reader:
        # Save First Row with headers
        if rownum == 0:
            header = row
            header = [x.lower() for x in header]
        else:
            colnum = 0
            for col in row:
                # print (rownum,header[colnum],col)
                rec[header[colnum]] = col
                colnum += 1
        rownum += 1
        # print(rownum,rec)
        if rec:
            try:
                client = aerospike.client(config).connect()
                # Write a record
                client.remove((ns, sets, str(rownum)))
            except Exception as e:
                import sys
                print("error: {0}".format(e), file=sys.stderr)
        
            # Close the connection to the Aerospike cluster
            client.close()
        rec = {}

def drive(mode, file, ns, sets):
    if mode == 'load':
        load(file, ns, sets)
    else:
        delete(file, ns, sets)
        
if __name__ == '__main__':
    #file = '/home/azureuser/Aerospike/data/customer/vehicle_recall.csv'
    file = '/home/azureuser/Aerospike/data/customer/vehicle_service.csv'
    ns = 'dev'
    #sets = 'vehicle_recall'
    sets = 'vehicle_service'
    drive('load', file, ns, sets)
# Out:
# Load and delete Vehicle data
#
#
# ('dev', 'vehicle_service', None, bytearray(b'\xe1\xb5&\xe0\xd2\x8f\x9e\xc7K\xe7\x1e<.]L\x99i\xc4\x80M')) {'service_type': 'General-Free', 'service_date': '10/9/2007', 'mileage': '500', 'vehicle_no': '84857', 'service_amount': '0'}
# ('dev', 'vehicle_service', None, bytearray(b'u\xc5\x88^\x15\x0b\xd9\xcaRrL\xfb\xa5\x93\xf3\xba\xe0>\xbf\xd8')) {'service_type': 'General-Free', 'service_date': '10/9/2005', 'mileage': '300', 'vehicle_no': '66714', 'service_amount': '0'}
# ('dev', 'vehicle_service', None, bytearray(b'\x13\xbaJ\xc51\xd0\x9f\xaf\x8d\xf7\xa9\xe3\x90\xb2\x1e\xc4\x86\x14>"')) {'service_type': 'General-Free', 'service_date': '10/9/2007', 'mileage': '800', 'vehicle_no': '70847', 'service_amount': '0'}
# ('dev', 'vehicle_service', None, bytearray(b'E\xdd]\xcd`\r\x88<\xd3\xfab\xf1\xf5\x02\x0b,\xa2\x1d}O')) {'service_type': 'General-Free', 'service_date': '10/9/2007', 'mileage':
) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '8800', 'vehicle_no': '85665', 'service_amount': '364'}
# ('dev', 'vehicle_service', None, bytearray(b'A\x90\xf6\x1fl>\xeb\x11\xf8d/\x901\xdc\t\x9cZ\xde\x87\x86')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '8814', 'vehicle_no': '82482', 'service_amount': '456.4'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe3\xd1\xb4\x0c?\xba|\xe8\x8a\xec+p\x8fp\x89\xe9\x17\x16\x83\xb4')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '9208', 'vehicle_no': '77511', 'service_amount': '509.6'}
# ('dev', 'vehicle_service', None, bytearray(b'\x17\x88\x98G7[S\x89\xd4\x10\xfbc\xde\x0b\xfc\xc3E40\x13')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '3406', 'vehicle_no': '63013', 'service_amount': '298.55'}
# ('dev', 'vehicle_service', None, bytearray(b"\xd77g\x9a\xd44\xc5\xb7IOP\\7\xa0\'\xad:\x06\t\xf9")) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '6890', 'vehicle_no': '71421', 'service_amount': '312.55'}
# ('dev', 'vehicle_service', None, bytearray(b' \n\xf2\xa8\x15\xe9\x1e\x8d^\xc8\x9e\x99\xfc\xf6\x93u-\xf3U\x97')) {'service_type': 'General-Paid', 'service_date': '8/5/2014', 'mileage': '7356', 'vehicle_no': '82111', 'service_amount': '388.5'}
# ('dev', 'vehicle_service', None, bytearray(b'h1\xcf_\x92>kb\xd9gW\x87\xfbo\xbc\xb5\xb1\x8e\x11\xf0')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '12010', 'vehicle_no': '65926', 'service_amount': '525'}
# ('dev', 'vehicle_service', None, bytearray(b'\xc7\xd7\x0f\xc6\xe1\x027\x83\xfb\xfaK:D\xa0\xa29\xee\xc3\xd9\xfe')) {'service_type': 'General-Paid', 'service_date': '8/5/2006', 'mileage': '11980', 'vehicle_no': '67623', 'service_amount': '356.3'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe2\x0b\x85\n5\xf2g\xd3\t(\xfa7-\xa2\xbc\x82\xd5\xc5\xbf2')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '10657', 'vehicle_no': '75573', 'service_amount': '370.3'}
# ('dev', 'vehicle_service', None, bytearray(b'\x8c\xeb\x85\x1f\x1d1\xe6\\\xaf\xef\x18(\x95\xa3\xa3\xde\xe1\x1a&V')) {'service_type': 'General-Paid', 'service_date': '8/5/2009', 'mileage': '13001', 'vehicle_no': '90071', 'service_amount': '422.8'}
# ('dev', 'vehicle_service', None, bytearray(b'7E\x84\x0e\xe1\xac\xd1\xa5\x114\x15\xf7\xe2\xb2\x9f\xc8\xa0\xba\xad\x81')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '14280', 'vehicle_no': '60479', 'service_amount': '509.95'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb53\xa8\x9c\xbe\r\x95^\x99\xf5\xefV\xbc\xe9\x16\x9d\xab\xddw\x1a')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '10098', 'vehicle_no': '82226', 'service_amount': '565.95'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe3\xd2\x15I uL\n\xa7\xf7\x99\xc4\xd1\xf9\x12\xd5$}p\xf6')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '12890', 'vehicle_no': '64968', 'service_amount': '365.05'}
# ('dev', 'vehicle_service', None, bytearray(b'v\xd4<\x14\xfc\x7f@\xbe9\xc0Z3m\x07\x90k@\xb2\x19q')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '8800', 'vehicle_no': '78862', 'service_amount': '506.8'}
# ('dev', 'vehicle_service', None, bytearray(b'\x08J?A\xc1\xca\xfb\x11\xb2I2\xfap\x1c\x07\x1a\xea\xec|\xce')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '8814', 'vehicle_no': '60064', 'service_amount': '381.85'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb3\xcb/\x91\x84\xd8\xc5#\x91\x1d*\x84}\xe1\xed4\x7f\xec\x97\xdd')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '9208', 'vehicle_no': '76684', 'service_amount': '399.35'}
# ('dev', 'vehicle_service', None, bytearray(b"f\xf2\x95c\x06\xe4\xce\x80\'F\x82Q\xf2\x830<\x97\x9cA\x83")) {'service_type': 'General-Paid', 'service_date': '8/5/2006', 'mileage': '3406', 'vehicle_no': '84967', 'service_amount': '424.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\xadC\xde\xa5\xb8\xa2\xe1BV\xa8\r\xd0\xab\x81\x8c\x98|\xa5\xff\xef')) {'service_type': 'General-Paid', 'service_date': '8/5/2009', 'mileage': '6890', 'vehicle_no': '76890', 'service_amount': '438.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\xba\xad\xe0\xea\x1a\xaf\x17(\xba\xaf\xc0\xa0j\x9bi\xe2\x95ya\x9b')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '7356', 'vehicle_no': '77719', 'service_amount': '483.7'}
# ('dev', 'vehicle_service', None, bytearray(b'9\xb9\x007\x9cJ\xb1\xd2\xd8\x8b\xc5\xe8Iw\x9f\x0f\xe5n]\xb2')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '15000', 'vehicle_no': '81355', 'service_amount': '676.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\r:\xfcy\x9b\x9c\x1c\xd2\x98z\xad\xbb\xeb\x1d\x9dh\x8e\xd5\x06\xff')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '12010', 'vehicle_no': '84180', 'service_amount': '676.2'}
# ('dev', 'vehicle_service', None, bytearray(b'c\x9ce\xe64\x0b\xb46\xe76]Z\xb5\x81\xfeN3\xd5\xfa\xa1')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '11980', 'vehicle_no': '73781', 'service_amount': '697.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\x8d\xf0#\xdfh\xae\x93\xfb\xd6\xdf\xe5\xd0 n"=m\xcdz\xde')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '10657', 'vehicle_no': '85235', 'service_amount': '276.5'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb2\xb1E\x0b?\xfa8T\xb4\xf8k\xdeW|\xc1\xdbG(`\xbe')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '14280', 'vehicle_no': '89200', 'service_amount': '322.35'}
# ('dev', 'vehicle_service', None, bytearray(b"\xc2\x11\xe2\xc7zX\x15\'\x1d\n\xc8\xf5\xa9\xa0\x81\xab\xd4O\x86\xa1")) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '10098', 'vehicle_no': '59888', 'service_amount': '364'}
# ('dev', 'vehicle_service', None, bytearray(b'\x84\xfa3+\xae\xfd\x89\x033\xfc\xcet\xbd\xff\xf6\xcaf{\x95\xdf')) {'service_type': 'General-Paid', 'service_date': '8/5/2017', 'mileage': '12890', 'vehicle_no': '86310', 'service_amount': '456.4'}
# ('dev', 'vehicle_service', None, bytearray(b'r\x0b\x96\xfd\x8b\xe1\xf8\xa6\x8f\xfa\x94\xd9i(\ry0\xf9\xbc\x94')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '7800', 'vehicle_no': '62612', 'service_amount': '509.6'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe4\x13\x8e\xf4s+\x17\x14@\xdf\x1b\x8d\xd3C\x17\r\x9d\x03\xa3H')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '8800', 'vehicle_no': '65609', 'service_amount': '298.55'}
# ('dev', 'vehicle_service', None, bytearray(b"?\x82|Eu\x9c9\x8db+M0\x7f\'\x96\x14{\xf6\xa6\xab")) {'service_type': 'General-Paid', 'service_date': '8/5/2006', 'mileage': '8814', 'vehicle_no': '68579', 'service_amount': '312.55'}
# ('dev', 'vehicle_service', None, bytearray(b"\x94s\x80[\xe4\'\t\xc3\x81\xa6B\xba\xa1\xae\xe4\xfd\x87\xb3L*")) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '9208', 'vehicle_no': '80770', 'service_amount': '388.5'}
# ('dev', 'vehicle_service', None, bytearray(b'(\xfdU\xe2\xa2\x897dSs\xc4\x83\xbff\xb51\xac\xc3\xb7\xd7')) {'service_type': 'General-Paid', 'service_date': '8/5/2015', 'mileage': '3406', 'vehicle_no': '81546', 'service_amount': '469'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb2\xc2t\xd7]c\xb9\xfdN\xdc\xb8V\xac\x02\xa5*\xa7\x1a\xd0s')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '7356', 'vehicle_no': '76990', 'service_amount': '356.3'}
# ('dev', 'vehicle_service', None, bytearray(b'.\x9d\x1f\xf2\x7f\xf4\xca\xff\x1a\xa43\xa9\x03\xb4\x8e8>\xa1\xcb\xed')) {'service_type': 'General-Paid', 'service_date': '8/5/2015', 'mileage': '15000', 'vehicle_no': '76400', 'service_amount': '370.3'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb4@:\xf0!\x10\xa6\xb2\\\xd7\xa9\x03z\xbfAG<\xee\x01\x90')) {'service_type': 'General-Paid', 'service_date': '8/5/2014', 'mileage': '11980', 'vehicle_no': '69984', 'service_amount': '509.95'}
# ('dev', 'vehicle_service', None, bytearray(b'8q\xaa\xf2\xff\xc2k\x921`Hh\x18\xa3\xfe\xf8\xe8\xafw\xb8')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '10657', 'vehicle_no': '71684', 'service_amount': '565.95'}
# ('dev', 'vehicle_service', None, bytearray(b'1b\x91\x81\xc7Qj\xa8\x05\xa9b\x96\x1e\x82\x84\x86\x90\xfd5>')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '13001', 'vehicle_no': '80298', 'service_amount': '365.05'}
# ('dev', 'vehicle_service', None, bytearray(b'\xbc\xcc\x16xxlb\xbb^\xb4\x0c\xde\xd7/07\xe8\xa5\x83\x0c')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '14280', 'vehicle_no': '74809', 'service_amount': '382.55'}
# ('dev', 'vehicle_service', None, bytearray(b'O\xc4\xb4q\x0e\x85\xe2]\x84ErI-\x94\xbd\x91\xdbE\x0fT')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '10098', 'vehicle_no': '88190', 'service_amount': '506.8'}
# ('dev', 'vehicle_service', None, bytearray(b'\xf7,!\x8dO\xa12\x95\xc10\xec\x00sR\xe8&\x9a6\xda\xfd')) {'service_type': 'General-Paid', 'service_date': '8/5/2015', 'mileage': '12890', 'vehicle_no': '87042', 'service_amount': '381.85'}
# ('dev', 'vehicle_service', None, bytearray(b'\xd9\\\xa7\xa0\x1a\xe4\x04B\x7f\x99\xed\xb4bb\x11\x11\x8en5\\')) {'service_type': 'General-Paid', 'service_date': '8/5/2014', 'mileage': '7800', 'vehicle_no': '86518', 'service_amount': '399.35'}
# ('dev', 'vehicle_service', None, bytearray(b'`\x11\xab\x1b\x04@r\xa5b\x84*\x86\xc9\xf8\xeb;\x0e!\x98,')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '8800', 'vehicle_no': '71188', 'service_amount': '424.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb7\xa5\xda\x7fL+\x82\xe0\x1dmQ\xe1\xc0\xa3\xfd\x98i\xb7\xe5\xa4')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '3406', 'vehicle_no': '68201', 'service_amount': '676.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\xc9\xf3\x1e\xcb!\xa5w\xcb\x7f\xb1\xac\x18I\x93\x9fQ\x11\x0fh\xd6')) {'service_type': 'General-Paid', 'service_date': '8/5/2013', 'mileage': '6890', 'vehicle_no': '86579', 'service_amount': '676.2'}
# ('dev', 'vehicle_service', None, bytearray(b'i\x00\x17\xc5T\xfc\x9e\x04eF\xc5\x1am\xe2\\r0\xe7\xfaI')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '7356', 'vehicle_no': '65150', 'service_amount': '697.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\x89\xc8\xd2T\x10\xdd\xad\xb8,\x9b.\xfa\xfcLX4\x90\x0ezV')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '15000', 'vehicle_no': '86773', 'service_amount': '276.5'}
# ('dev', 'vehicle_service', None, bytearray(b'e9\x92\xees,k9\xf3P\xd6\x90\x9b\xbc\xce\xe0v\xa8\xe8\xa4')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '12010', 'vehicle_no': '61537', 'service_amount': '290.5'}
# ('dev', 'vehicle_service', None, bytearray(b'\x04\x1e\xe6c\x01u\xb0N\xba\xf9\x17=*=9\xb9\xf4\xe0j\x1e')) {'service_type': 'General-Paid', 'service_date': '8/5/2013', 'mileage': '11980', 'vehicle_no': '78567', 'service_amount': '322.35'}
# ('dev', 'vehicle_service', None, bytearray(b'\r\x82W\x0c\x99h\xad8}z9<\x90ex4\xde\xcdD\xfd')) {'service_type': 'General-Paid', 'service_date': '8/5/2014', 'mileage': '10657', 'vehicle_no': '59578', 'service_amount': '364'}
# ('dev', 'vehicle_service', None, bytearray(b'\x06@\xa3\x1e`\tN\xdf\xde?\t\xca\x19\xfd\xe4\xc3^\xd6x\xfc')) {'service_type': 'General-Paid', 'service_date': '8/5/2013', 'mileage': '13001', 'vehicle_no': '87378', 'service_amount': '456.4'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb9\xa7\x024\x8d\x08\x9b\xcff;\xc6\xdc3\xf9\xfc9\x999\x07m')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '14280', 'vehicle_no': '89978', 'service_amount': '509.6'}
# ('dev', 'vehicle_service', None, bytearray(b'\x11`\xd0\xb0\x07\x81\xeb\xd0<\x97\x9f\xb6h\xc5U\x87h\xdf\x1eS')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '10098', 'vehicle_no': '82049', 'service_amount': '298.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\x9d\x839\x8a\xd3`\xe7\x0c\xa9\x0f\xec\xf0\xdcasD\xff\x95\xa5{')) {'service_type': 'General-Paid', 'service_date': '8/5/2009', 'mileage': '12890', 'vehicle_no': '69452', 'service_amount': '312.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\xc8\xc3\x8d\x7f\xc4\xb9D\xa4k=\x00\xbc\x9b\x8f\xdb\x1b\xa6w\x12\xc2')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '7800', 'vehicle_no': '59700', 'service_amount': '388.5'}
# ('dev', 'vehicle_service', None, bytearray(b'W\xbbA\x8d\x8bO\xb1\xad\x7f\x19@d\xe7\x14\x95*DF\xa1\xcf')) {'service_type': 'General-Paid', 'service_date': '8/5/2006', 'mileage': '8800', 'vehicle_no': '64569', 'service_amount': '469'}
# ('dev', 'vehicle_service', None, bytearray(b':\xd8G\x8b\t\xa4>\x1a\xd1<\x9c+\xe3\x06\x08\t\x9c\xcf\x16\xce')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '8814', 'vehicle_no': '85497', 'service_amount': '525'}
# ('dev', 'vehicle_service', None, bytearray(b'\xd57\x14vxB\x14\x9e\x9c?\x92o\xfb\xccf\xd9wt\xc8\xe0')) {'service_type': 'General-Paid', 'service_date': '8/5/2009', 'mileage': '9208', 'vehicle_no': '87457', 'service_amount': '356.3'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe0\xd6X9"\xb4\xa6U\xe1\x1b\xd4I\x1d\x11o\xce\x17\xcd\xf6:')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '3406', 'vehicle_no': '75757', 'service_amount': '370.3'}
# ('dev', 'vehicle_service', None, bytearray(b"\xdcXJ\xf4|\xfa\xfaWj\x83\xecH\xb9I\xf9\xa9\'\xbb\x05\xa5")) {'service_type': 'General-Paid', 'service_date': '8/5/2009', 'mileage': '6890', 'vehicle_no': '63676', 'service_amount': '422.8'}
# ('dev', 'vehicle_service', None, bytearray(b'\xea\x96\xe7\xb3\xf4[\x9e\xa0\x07\xee%z\xd22\x16-\x0f\x85;\x9a')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '7356', 'vehicle_no': '60028', 'service_amount': '509.95'}
# ('dev', 'vehicle_service', None, bytearray(b'\xddL\x88\xa0\x94$\xc00\x00N\xb2B\x07\xb0 $\xa3{"\xad')) {'service_type': 'General-Paid', 'service_date': '8/5/2015', 'mileage': '15000', 'vehicle_no': '71733', 'service_amount': '565.95'}
# ('dev', 'vehicle_service', None, bytearray(b'\x9d\x1c\x890\xe3\xa82\x95\xe5\x165[u\xd3\xa3;\x9f#\xfa\xe2')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '12010', 'vehicle_no': '60734', 'service_amount': '365.05'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe2\x1d\x0f\x81\x11\x11\xe8\xf9x\xc1\xfd\xe2\xfa\x04A\n\xb5\xb4\x00\x8a')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '11980', 'vehicle_no': '83651', 'service_amount': '382.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\xa3\xd3\xf3\xa3\xe7\xd9\xf0\x82\xffjUK6\x7fA_\x12\x9e\xf4$')) {'service_type': 'General-Paid', 'service_date': '8/5/2013', 'mileage': '10657', 'vehicle_no': '63968', 'service_amount': '506.8'}
# ('dev', 'vehicle_service', None, bytearray(b'\xae\xabU\xd1n\xc5\xe1\xca\xf6\xf9\x08\xea\xa8\xadJf\x03!$)')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '13001', 'vehicle_no': '71393', 'service_amount': '381.85'}
# ('dev', 'vehicle_service', None, bytearray(b'\xbb\x89s}\xdc\xaa\x01\xea\xfe`)\xf0^u\x16@\x12Z\x8a\xe7')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '14280', 'vehicle_no': '78393', 'service_amount': '399.35'}
# ('dev', 'vehicle_service', None, bytearray(b'\x0b(\xda\xaf\xbd\x14\xec7yp\xcc\xad\x14\x0eMQ\x88E\xf4\xd0')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '10098', 'vehicle_no': '80733', 'service_amount': '424.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\x13h\xadf\x1f\xf8\xfd2\xac\x86\xe5\n\xec\xda:]\xd4\xcaX\xb0')) {'service_type': 'General-Paid', 'service_date': '8/5/2013', 'mileage': '12890', 'vehicle_no': '73625', 'service_amount': '438.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\x1c\x1ft\xcb\xcb\xd4p\xb5\x19\xf7V\x90\x00`\xfc\xc7\x8f\xf3~}')) {'service_type': 'General-Paid', 'service_date': '8/5/2017', 'mileage': '7800', 'vehicle_no': '80757', 'service_amount': '483.7'}
# ('dev', 'vehicle_service', None, bytearray(b'\xd4\xaf}\xba\x7f\x15\xf6\xd4\x04\x1bA\x88\x9e\xcaG\xba;C\x92\x98')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '8800', 'vehicle_no': '82567', 'service_amount': '676.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\xba\x8e\x8d\xc0\xaa>\x04\x7f\x04\xe5\x00\xb72i\t\xb7f\\D\x88')) {'service_type': 'General-Paid', 'service_date': '8/5/2010', 'mileage': '8814', 'vehicle_no': '69078', 'service_amount': '676.2'}
# ('dev', 'vehicle_service', None, bytearray(b'J\xe9k\xe5B\x0c\xe7\x87w{\x85\x14\xcd\xa1\xcd\x0f-\x8a/\xc2')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '9208', 'vehicle_no': '86574', 'service_amount': '697.2'}
# ('dev', 'vehicle_service', None, bytearray(b'\xfa\xefY\x13\xa5\x03\xe7\xe9:H2\x84\x8e)=4\xda\x8a\x0c\xbb')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '3406', 'vehicle_no': '65661', 'service_amount': '276.5'}
# ('dev', 'vehicle_service', None, bytearray(b'\x9a\x9f]7\xfb\x98\xfaD\x88\x04\xc8mK\x98\xcd\xd1\x03>\x8d#')) {'service_type': 'General-Paid', 'service_date': '8/5/2006', 'mileage': '6890', 'vehicle_no': '84272', 'service_amount': '290.5'}
# ('dev', 'vehicle_service', None, bytearray(b'\xdd#\xc0(\xd8\x99\x94\x8793P\xb6N:.0\xca\x0b\x95\xea')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '7356', 'vehicle_no': '88424', 'service_amount': '322.35'}
# ('dev', 'vehicle_service', None, bytearray(b'\n))\xc3\xdc]\x8f\xe3\xc3Pi\xf9h\x96\xedF\xd0\xa2\xde\x17')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '15000', 'vehicle_no': '59166', 'service_amount': '364'}
# ('dev', 'vehicle_service', None, bytearray(b'\x0fe\xb5\xba \xd8\xaad\x99\n\xc1\xceI\xac\xa1\x9f\\\x91\x88/')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '12010', 'vehicle_no': '61554', 'service_amount': '456.4'}
# ('dev', 'vehicle_service', None, bytearray(b'E:\x10\xa9\xe8\x1cy\xd5\xbcdb33m\x8e,\xff\xc8\x0c,')) {'service_type': 'General-Paid', 'service_date': '8/5/2013', 'mileage': '11980', 'vehicle_no': '67488', 'service_amount': '509.6'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe6\xd0H6\xe6\xd7{\xfeU\xef\xfc\x8c\x115\xaa\xef\xac\xdb\xc8\x9a')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '10098', 'vehicle_no': '59870', 'service_amount': '298.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe1\x86\x89\xefh-e\xb8d[AoL\xeb\xb2\x02\x15\xe6-\x06')) {'service_type': 'General-Paid', 'service_date': '8/4/2016', 'mileage': '7800', 'vehicle_no': '77300', 'service_amount': '388.5'}
# ('dev', 'vehicle_service', None, bytearray(b'P\xae\x91\xa0\x8f2\xa0y\x1f\xeb\xba\x13\xd1\x92\xd6\x1a\xa5?\xe0\xab')) {'service_type': 'General-Paid', 'service_date': '8/5/2011', 'mileage': '8800', 'vehicle_no': '83280', 'service_amount': '469'}
# ('dev', 'vehicle_service', None, bytearray(b'\x86\r\x1eJ\x82\xc1\xa5*r[\tUOK\x1d\x11\x89j\x10\xb1')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '8814', 'vehicle_no': '85779', 'service_amount': '525'}
# ('dev', 'vehicle_service', None, bytearray(b'zw\xc15\xb4\x86\xf1\x17t\x94;\xf6\x0142\xab\x8a\xdb\xbe\xaf')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '9208', 'vehicle_no': '77830', 'service_amount': '356.3'}
# ('dev', 'vehicle_service', None, bytearray(b'y`wcV\xbe\xa3\xd9\x00\xb5\x8e\x7f\xa0\xda\x9c\xab\xd4vb\x87')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '6890', 'vehicle_no': '68056', 'service_amount': '422.8'}
# ('dev', 'vehicle_service', None, bytearray(b'O\xceo\xd7\xae3\xbft\xf2{\x90\xb728P\x95,\xc1D\x90')) {'service_type': 'General-Paid', 'service_date': '8/5/2014', 'mileage': '7356', 'vehicle_no': '66201', 'service_amount': '509.95'}
# ('dev', 'vehicle_service', None, bytearray(b'm\xcd\xa8\x00\xfc6r\x983\xa7^\xed\xb9\x19\xe4\x97.\xa0\xa2\x0b')) {'service_type': 'General-Paid', 'service_date': '8/5/2007', 'mileage': '15000', 'vehicle_no': '81064', 'service_amount': '565.95'}
# ('dev', 'vehicle_service', None, bytearray(b'\x07\x18\xc3(\xfaj\xec\x05\xe4\xcfG\x88\x87n\x9b+\x04\xeen\xf8')) {'service_type': 'General-Paid', 'service_date': '8/4/2012', 'mileage': '12010', 'vehicle_no': '60448', 'service_amount': '365.05'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe2\x1d\x8e=*\xe8\x14YrB*\x9f`\x95"\xb1\t\x97\xeaY')) {'service_type': 'General-Paid', 'service_date': '8/5/2009', 'mileage': '11980', 'vehicle_no': '60920', 'service_amount': '382.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\x11\xab\x9e\x83\x08x`E\x8d\xcec\xdc\x05>5\xb3\xfb\xcc\xf9\x8e')) {'service_type': 'General-Paid', 'service_date': '8/4/2008', 'mileage': '10657', 'vehicle_no': '86143', 'service_amount': '506.8'}
# ('dev', 'vehicle_service', None, bytearray(b'\xdc\x10Al\xc7\x9ax\xf9\xce\x180\x0b}\nF\x18\x1dA\x13\xbf')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '20098', 'vehicle_no': '84857', 'service_amount': '304.15'}
# ('dev', 'vehicle_service', None, bytearray(b'Z\x12#\x92\xefE\xd0\x03\xe0\xcc4e\xa3\x8e\xaf\xab\xe0\xfb\x8a\x9e')) {'service_type': 'General-Paid', 'service_date': '7/1/2007', 'mileage': '22890', 'vehicle_no': '66714', 'service_amount': '319.55'}
# ('dev', 'vehicle_service', None, bytearray(b'HM\x1bk.W^&Iza\xaa\xd6Z9\xf3\xb4\x88h\xd9')) {'service_type': 'Accident', 'service_date': '6/30/2009', 'mileage': '17800', 'vehicle_no': '70847', 'service_amount': '10000'}
# ('dev', 'vehicle_service', None, bytearray(b'\xc4\x10\xac\xe3\tD\xc0*\xf1\x94H\x1d>\x8e@g\xedf\xcc\xf8')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '18800', 'vehicle_no': '85665', 'service_amount': '400.4'}
# ('dev', 'vehicle_service', None, bytearray(b'\x1aN\xbc_\x8d\xb7f\xb1qBmW+&\xce/\xce|\x9b\x9e')) {'service_type': 'General-Paid', 'service_date': '6/30/2012', 'mileage': '18814', 'vehicle_no': '82482', 'service_amount': '502.04'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb8\xcaN\x89\xdf\x11 ,\xf1\x1b\xd2\xc6\x94lz\x18\x9d9\xc6\x9a')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '19208', 'vehicle_no': '77511', 'service_amount': '560.56'}
# ('dev', 'vehicle_service', None, bytearray(b'\xfc\x94\xcdYH\xa1J\x89\xca\xc1\x01\x9a\xd2yv\xb1\x8f\xa9\x11X')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '13406', 'vehicle_no': '63013', 'service_amount': '328.405'}
# ('dev', 'vehicle_service', None, bytearray(b'[K\xf6\xf8B\x1cC\xc0\x89\xdb\x86h%\xa1+*\x14\x9f\x02r')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '16890', 'vehicle_no': '71421', 'service_amount': '343.805'}
# ('dev', 'vehicle_service', None, bytearray(b'l\x0c\xba]\xfdVZ[\xa0y\xff\x1c$j\\\xd8\x04\x81k\xbc')) {'service_type': 'General-Paid', 'service_date': '7/1/2015', 'mileage': '17356', 'vehicle_no': '82111', 'service_amount': '427.35'}
# ('dev', 'vehicle_service', None, bytearray(b'K\xa2\xd9\xa9\xbc\x043T\xe8\xd6/\xf2[\xc5\xea\xf5\xfb\xf3>M')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '22010', 'vehicle_no': '65926', 'service_amount': '577.5'}
# ('dev', 'vehicle_service', None, bytearray(b'\xf8P\x9c\x11\xbe)\xe6\x04\xb7_w\\`\xca\x97v\x82zY(')) {'service_type': 'General-Paid', 'service_date': '7/1/2007', 'mileage': '21980', 'vehicle_no': '67623', 'service_amount': '391.93'}
# ('dev', 'vehicle_service', None, bytearray(b'B\x11\\\xf78\xad\xdf\x06\xf7jn\xcd\xe4e!t\x199\xf2\x04')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '20657', 'vehicle_no': '75573', 'service_amount': '407.33'}
# ...
# ('dev', 'vehicle_service', None, bytearray(b'S\xc6lE\x13l\xcfj\x86f\x9b,\xe2\x96\xb5\x8b\n\xf9e\x0c')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '21980', 'vehicle_no': '73781', 'service_amount': '766.92'}
# ('dev', 'vehicle_service', None, bytearray(b':\x01\x02r\x06\x05\xd1\xc3\xcc\x82ZF\xc6_DM\xcc\x97\xd2I')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '20657', 'vehicle_no': '85235', 'service_amount': '304.15'}
# ('dev', 'vehicle_service', None, bytearray(b'p>\xf68\nP}\xe1i\xd7\xda\xec\xe2\xedF:\x1c\xc4\xb5\xf6')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '24280', 'vehicle_no': '89200', 'service_amount': '354.585'}
# ('dev', 'vehicle_service', None, bytearray(b'\xd3\xe0\x05\x86\x0b7\xcb\xb5\xa6\x1bd_\x88b\xd3\x7fq\x8d\xd6\xbe')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '20098', 'vehicle_no': '59888', 'service_amount': '400.4'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb3\x04\xfc/\xb0.\x0e\x153\xbbO\xb9\xd4\xd6\x1f/|V\xc6O')) {'service_type': 'General-Paid', 'service_date': '7/1/2018', 'mileage': '22890', 'vehicle_no': '86310', 'service_amount': '502.04'}
# ('dev', 'vehicle_service', None, bytearray(b"\xf8I\xf3\x11\x9f\x92oi\'\xd8\x175\x17\xfa\x95\x0e[2\x15\x08")) {'service_type': 'General-Paid', 'service_date': '6/30/2012', 'mileage': '17800', 'vehicle_no': '62612', 'service_amount': '560.56'}
# ('dev', 'vehicle_service', None, bytearray(b'83\x1a\x96\x0b!F\xc4T\xfb|\xd1\x17\x00\x91\xdds\xca\xf9\x97')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '18800', 'vehicle_no': '65609', 'service_amount': '328.405'}
# ('dev', 'vehicle_service', None, bytearray(b'A\x87\xd7\xdd\x19\xeb\xb0\xe6\x0b|\xaf\x9fM\xf72\xb4\xf5\xda\x81\xc3')) {'service_type': 'General-Paid', 'service_date': '7/1/2007', 'mileage': '18814', 'vehicle_no': '68579', 'service_amount': '343.805'}
# ('dev', 'vehicle_service', None, bytearray(b'\x1c]\xcf\xb7\x06\xb4c \xa7V\xa9\r\xe0\x18\x95aR\xd54\x81')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '19208', 'vehicle_no': '80770', 'service_amount': '427.35'}
# ('dev', 'vehicle_service', None, bytearray(b'P\xeb\x80\xefWz\x02\xf4\xbfoz\xe2\x1b\xa2\xc7MS\xed&~')) {'service_type': 'General-Paid', 'service_date': '6/30/2016', 'mileage': '13406', 'vehicle_no': '81546', 'service_amount': '515.9'}
# ('dev', 'vehicle_service', None, bytearray(b'\xf0\r\x16\xf5\x1b\x037\xf0\x99?\xc2\x87>\xbb\x95\xf9F\xff3X')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '17356', 'vehicle_no': '76990', 'service_amount': '391.93'}
# ('dev', 'vehicle_service', None, bytearray(b'\xcaTP\xe9\xd9V\xf3 *\xb2H\x13\t\x9e\ra\xb7\x9bQ\xaa')) {'service_type': 'General-Paid', 'service_date': '6/30/2016', 'mileage': '25000', 'vehicle_no': '76400', 'service_amount': '407.33'}
# ('dev', 'vehicle_service', None, bytearray(b'\xac~\xd8L?\x91n\x81\xd2\x82\xa3\x9a\xdc\xe9\xc4\xf8C:~#')) {'service_type': 'General-Paid', 'service_date': '7/1/2015', 'mileage': '21980', 'vehicle_no': '69984', 'service_amount': '560.945'}
# ('dev', 'vehicle_service', None, bytearray(b'O\xc8\xd5E\t`\xac+\xfb\x92\x7f\x1a\xdbQ\xd9\xe2[\x9ak\xa3')) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '20657', 'vehicle_no': '71684', 'service_amount': '622.545'}
# ('dev', 'vehicle_service', None, bytearray(b'\xeeiN2U\x86U\x8d\x82\xa8\xa8L\xeez\x16\xbez\xdb\xfcZ')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '23001', 'vehicle_no': '80298', 'service_amount': '401.555'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe6\xea\x0f`\xb9h\xc4\xc6\xddWx+\x10\xa2\x18\xb6\xec\xd8Z\x1a')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '24280', 'vehicle_no': '74809', 'service_amount': '420.805'}
# ('dev', 'vehicle_service', None, bytearray(b'q\x11o\xb8\x0b\xdf\xdb\xa2?\xbf\x8f\xadi\x85\xf2\xd8\xe4\xe1\xd41')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '20098', 'vehicle_no': '88190', 'service_amount': '557.48'}
# ('dev', 'vehicle_service', None, bytearray(b'\xcf,=<S\xe4\x8e_\xa0t\xab\x96\xe9oZ\x9c\x0c99p')) {'service_type': 'General-Paid', 'service_date': '6/30/2016', 'mileage': '22890', 'vehicle_no': '87042', 'service_amount': '420.035'}
# ('dev', 'vehicle_service', None, bytearray(b'\xa4>O\x88\xc0\x0br\xcb\xeb\xf9\x80_\xe5.Y\xcb\x8bR\x85\x1a')) {'service_type': 'General-Paid', 'service_date': '7/1/2015', 'mileage': '17800', 'vehicle_no': '86518', 'service_amount': '439.285'}
# ('dev', 'vehicle_service', None, bytearray(b'\xcb\xa70n?\xc6\x0b\x18\xa4\xdb\x91k\x89\xb5%\x97\xb41\x94\xbc')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '18800', 'vehicle_no': '71188', 'service_amount': '467.005'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe5\x8e\x15H\x0b\xcb5\x9d\xb56\x9d\x1arT[1{~"Z')) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '13406', 'vehicle_no': '68201', 'service_amount': '743.82'}
# ('dev', 'vehicle_service', None, bytearray(b'{f9\x02\xf4\xebg\x96m~\x91\xef\xad\xb6\x03\xfc\xd2v\xa6\x16')) {'service_type': 'General-Paid', 'service_date': '7/1/2014', 'mileage': '16890', 'vehicle_no': '86579', 'service_amount': '743.82'}
# ('dev', 'vehicle_service', None, bytearray(b'e\x9d)\xd4;\xf99\xfd\xfb\xf9\x8cI\xba\xedI\x18k3\xda3')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '17356', 'vehicle_no': '65150', 'service_amount': '766.92'}
# ('dev', 'vehicle_service', None, bytearray(b'w\xab\x93\xb2\xd9\xb2]W\xa0\xba\xb1P\xe6\xadN_M{\x91\x1d')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '25000', 'vehicle_no': '86773', 'service_amount': '304.15'}
# ('dev', 'vehicle_service', None, bytearray(b"\xcc5\'\x89a\xa6\xc8K\xd3\xfb\x0c\x03{\x8ct\x0e\xac\x8e\xe1\xd2")) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '22010', 'vehicle_no': '61537', 'service_amount': '319.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\x994!m\xcf\x8e\x91`\xe1&\xde\xf6`U,\xfde\xcd*\x8e')) {'service_type': 'General-Paid', 'service_date': '7/1/2014', 'mileage': '21980', 'vehicle_no': '78567', 'service_amount': '354.585'}
# ('dev', 'vehicle_service', None, bytearray(b'\x8a\x81pt\xb2[\x1b\x18\xaah\x8eJ\xfb\r\xa9aq\xd9\\3')) {'service_type': 'General-Paid', 'service_date': '7/1/2015', 'mileage': '20657', 'vehicle_no': '59578', 'service_amount': '400.4'}
# ('dev', 'vehicle_service', None, bytearray(b'1E]Nm\xdag\xfc\xdf\xeeLq\x8a\x85{4d\xd8H\x1f')) {'service_type': 'General-Paid', 'service_date': '7/1/2014', 'mileage': '23001', 'vehicle_no': '87378', 'service_amount': '502.04'}
# ('dev', 'vehicle_service', None, bytearray(b'g?\nE!\xb0\x9c\xef\x96\xde\xfb\x81\xb6a\xbd8\xccat\xdf')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '24280', 'vehicle_no': '89978', 'service_amount': '560.56'}
# ('dev', 'vehicle_service', None, bytearray(b'E\x90\xddh\n\x19\xd7\xe8\xd7J\x9d\xd4|\xbf\xee\x8c\xb2F\x08\x9b')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '20098', 'vehicle_no': '82049', 'service_amount': '328.405'}
# ('dev', 'vehicle_service', None, bytearray(b'\xd6U\x0b\x80;\x82\x84&H8-\xfd\x8f\xf8 a\x94\\cs')) {'service_type': 'General-Paid', 'service_date': '7/1/2010', 'mileage': '22890', 'vehicle_no': '69452', 'service_amount': '343.805'}
# ('dev', 'vehicle_service', None, bytearray(b';\x01MZb\xe2\x99&K\x7fn\x93_9j\x8f\xec,_\xa2')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '17800', 'vehicle_no': '59700', 'service_amount': '427.35'}
# ('dev', 'vehicle_service', None, bytearray(b'J\x9c.\x9dH\xcd\x96@+\xb5.\xca\xd1\xb1\xd2\xca~\xd1\xef\x9a')) {'service_type': 'General-Paid', 'service_date': '7/1/2007', 'mileage': '18800', 'vehicle_no': '64569', 'service_amount': '515.9'}
# ('dev', 'vehicle_service', None, bytearray(b'\x7f0@\xe6f\x11\x89\xcd\xbd\x91y\xbc-\xf8n\x92\x13rvd')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '18814', 'vehicle_no': '85497', 'service_amount': '577.5'}
# ('dev', 'vehicle_service', None, bytearray(b"V\xa3\xb65\x812\xb7\x94!1d\xae\x0f\xdfl\xf4W\'\x81Q")) {'service_type': 'General-Paid', 'service_date': '7/1/2010', 'mileage': '19208', 'vehicle_no': '87457', 'service_amount': '391.93'}
# ('dev', 'vehicle_service', None, bytearray(b'\x8f\x9a\xb7P\xddn*\x19P\xac\xffvs\xa6\x08:\x1b\xe5\x84\x9c')) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '13406', 'vehicle_no': '75757', 'service_amount': '407.33'}
# ('dev', 'vehicle_service', None, bytearray(b'\x93\xf5\x03\x92\x05\x02\xd1={}\xccU\x8e\xaf\x9b\xa91\x18f\xb6')) {'service_type': 'General-Paid', 'service_date': '7/1/2010', 'mileage': '16890', 'vehicle_no': '63676', 'service_amount': '465.08'}
# ('dev', 'vehicle_service', None, bytearray(b' \xf7z!\xc3\xd47\xe39E&\t\xe3\xe74\xccHl;\x01')) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '17356', 'vehicle_no': '60028', 'service_amount': '560.945'}
# ('dev', 'vehicle_service', None, bytearray(b'\xf9\x1b\x10Z\xb0v\x83\x10\xb7\xd5\xa8^#\xc5\x0f\x04\x88\xe2R\x7f')) {'service_type': 'General-Paid', 'service_date': '6/30/2016', 'mileage': '25000', 'vehicle_no': '71733', 'service_amount': '622.545'}
# ('dev', 'vehicle_service', None, bytearray(b'Zu;%\x01\xd5\xa6\x86\x0e\x00\x0b\xf0\xa8^*kk\xab\x92\xf9')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '22010', 'vehicle_no': '60734', 'service_amount': '401.555'}
# ('dev', 'vehicle_service', None, bytearray(b'3\xce\x0b\xb7\xa9N\x1f&\xbd\xbaD\x0f\x1f\xca6u6 8\xfa')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '21980', 'vehicle_no': '83651', 'service_amount': '420.805'}
# ('dev', 'vehicle_service', None, bytearray(b'\xe6\x07\x10%L\xdc\xf9\xd7\x89\x05Q\xdem\x1bRNDI\x9c\xd6')) {'service_type': 'General-Paid', 'service_date': '7/1/2014', 'mileage': '20657', 'vehicle_no': '63968', 'service_amount': '557.48'}
# ('dev', 'vehicle_service', None, bytearray(b'\x8a\x83\xe7\xfehi\xa7\xff\x8c\xae\xe7\x07\x9a\x08\x9fx$\xdc\xa8\x8d')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '23001', 'vehicle_no': '71393', 'service_amount': '420.035'}
# ('dev', 'vehicle_service', None, bytearray(b'\xb32\xf0\xb7\x8fU\xf53Oly!\xae1M\x02\x0c\x92\x0bc')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '24280', 'vehicle_no': '78393', 'service_amount': '439.285'}
# ('dev', 'vehicle_service', None, bytearray(b'2\xa5"\xb0\x81\xed^\x1a\xf2\x7f|pa\x8d\x07\xcd\x0e\x7fVw')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '20098', 'vehicle_no': '80733', 'service_amount': '467.005'}
# ('dev', 'vehicle_service', None, bytearray(b'\xf6\xc2\xc5\xcb\x02,\x01\xdf\nE\xfb\x97o\xfcO\x8dr#\xec\xde')) {'service_type': 'General-Paid', 'service_date': '7/1/2014', 'mileage': '22890', 'vehicle_no': '73625', 'service_amount': '482.02'}
# ('dev', 'vehicle_service', None, bytearray(b'\x87\x82\x1e\xa2\x83{{x\xaah\xf4)\xea\x13}\xb9!\xb0\xb27')) {'service_type': 'General-Paid', 'service_date': '7/1/2018', 'mileage': '17800', 'vehicle_no': '80757', 'service_amount': '532.07'}
# ('dev', 'vehicle_service', None, bytearray(b"\xa3\xfa\xaa}\xa5=\x06\xf4iI+\xdb\xaa\xc6\xd8\xb28\xb6\'\x13")) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '18800', 'vehicle_no': '82567', 'service_amount': '743.82'}
# ('dev', 'vehicle_service', None, bytearray(b'\x9f\xcaz\xcd\x9d\x0e\x13\xa0\xabC\xbe\xbd\x13\xce?\xe9G\xa1\xb5\xf8')) {'service_type': 'General-Paid', 'service_date': '7/1/2011', 'mileage': '18814', 'vehicle_no': '69078', 'service_amount': '743.82'}
# ('dev', 'vehicle_service', None, bytearray(b'\xd9\xae\xb9\x1c\xc0G.\x11\x8eA\x92\x89p`E\x1e\x8cA\xc5\x0f')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '19208', 'vehicle_no': '86574', 'service_amount': '766.92'}
# ('dev', 'vehicle_service', None, bytearray(b'\xbd\x00\xf4\xa5\xa2\x94\xce&\x08\x1a\x8a\x92\x1d\xe8\x83\x17\x0f\xc9\xde~')) {'service_type': 'General-Paid', 'service_date': '6/30/2012', 'mileage': '13406', 'vehicle_no': '65661', 'service_amount': '304.15'}
# ('dev', 'vehicle_service', None, bytearray(b'\xcb\x81\xcc>\xe2|&\xcc$Uo\xe4(x\xf3J\xd7g7D')) {'service_type': 'General-Paid', 'service_date': '7/1/2007', 'mileage': '16890', 'vehicle_no': '84272', 'service_amount': '319.55'}
# ('dev', 'vehicle_service', None, bytearray(b'\x89|\xea/?\x82\xec\xe8l\xdd\xb6N=t\xf8\xc5v\x8d\xdb\x86')) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '17356', 'vehicle_no': '88424', 'service_amount': '354.585'}
# ('dev', 'vehicle_service', None, bytearray(b'} \x1f\x11\xd3\xb6\xbd\x80\r\xd4\x1f\xc6\xcf\xfc\xe7/\xbd\xc9\xd3\xc9')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '25000', 'vehicle_no': '59166', 'service_amount': '400.4'}
# ('dev', 'vehicle_service', None, bytearray(b'C\x00v\xa8\xdcoDl\xc9\xb0\\=w\x96&\xe16+\x83\x12')) {'service_type': 'General-Paid', 'service_date': '6/30/2012', 'mileage': '22010', 'vehicle_no': '61554', 'service_amount': '502.04'}
# ('dev', 'vehicle_service', None, bytearray(b'\xc0\xca\xdf\xfe\xd0\x13K\x9fH\xce_\x954\x8f\t4\xf0\xff\xdfb')) {'service_type': 'General-Paid', 'service_date': '7/1/2014', 'mileage': '21980', 'vehicle_no': '67488', 'service_amount': '560.56'}
# ('dev', 'vehicle_service', None, bytearray(b'\xafT=r\x0bO:\xbf\x7f\xea\xf5z`\xe9\x03&\x01\x18\x9b\x92')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '20098', 'vehicle_no': '59870', 'service_amount': '328.405'}
# ('dev', 'vehicle_service', None, bytearray(b'\x80\xae\x9fl/\xf6\xadU!\x1fZ\xdb\xf4\xd7\xe7\x971\xd5\xb3\xd3')) {'service_type': 'General-Paid', 'service_date': '6/30/2017', 'mileage': '17800', 'vehicle_no': '77300', 'service_amount': '427.35'}
# ('dev', 'vehicle_service', None, bytearray(b"\xcb\x10\xaa\xb3\'\x89\xb9\xfebX\xd2:\x11F\xdd\xa2\xaa\x8b\xdbA")) {'service_type': 'General-Paid', 'service_date': '6/30/2012', 'mileage': '18800', 'vehicle_no': '83280', 'service_amount': '515.9'}
# ('dev', 'vehicle_service', None, bytearray(b'\xaf\xb6\xe9Ue\x11h\xe2\xa9\x00\xec\xfbD7\x18\xda\xb9\xe2\xcb\xe2')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '18814', 'vehicle_no': '85779', 'service_amount': '577.5'}
# ('dev', 'vehicle_service', None, bytearray(b'dA\x1c\xb9pq\r\xd2\xdd\x99Yy<\x1b\xab\x16\xb7\xc6N\x82')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '19208', 'vehicle_no': '77830', 'service_amount': '391.93'}
# ('dev', 'vehicle_service', None, bytearray(b'm\xa8U\xa1\x97\xc1\x13\x97\x02|Ro\xb8\x9b(\xeb\xf2SW\xc9')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '16890', 'vehicle_no': '68056', 'service_amount': '465.08'}
# ('dev', 'vehicle_service', None, bytearray(b'eO\xdc;%"^h\xe4!M0\xdb\xdf\xd0\xa9\xf6J\x02!')) {'service_type': 'General-Paid', 'service_date': '7/1/2015', 'mileage': '17356', 'vehicle_no': '66201', 'service_amount': '560.945'}
# ('dev', 'vehicle_service', None, bytearray(b'QV/\x1b\xd8Z\xb3`\x1ay\xa5\x0c\x8f\x14\x94G\t\xe7"\xcd')) {'service_type': 'General-Paid', 'service_date': '6/30/2008', 'mileage': '25000', 'vehicle_no': '81064', 'service_amount': '622.545'}
# ('dev', 'vehicle_service', None, bytearray(b'\xbb(\xadT\xe2!\x0e\xeb\n\x1e\xb8\xdfnU\xb4\x98\xc0\xb2\x03j')) {'service_type': 'General-Paid', 'service_date': '6/30/2013', 'mileage': '22010', 'vehicle_no': '60448', 'service_amount': '401.555'}
# ('dev', 'vehicle_service', None, bytearray(b',\xbc\x1e9\x88\x17\xac\x13,\t\xbd|\xe5\x8f\x9a\x8a\xa9AE\xe8')) {'service_type': 'General-Paid', 'service_date': '7/1/2010', 'mileage': '21980', 'vehicle_no': '60920', 'service_amount': '420.805'}
# ('dev', 'vehicle_service', None, bytearray(b'\xc7t=GZ\x97\x92#\xaf\xe4\xd4\xb2T\x95\xcc\x8b\x07UIw')) {'service_type': 'General-Paid', 'service_date': '6/30/2009', 'mileage': '20657', 'vehicle_no': '86143', 'service_amount': '557.48'}

# %% [markdown]
# ### Create index for table dev.vehicle_recall
#
# Syntax - CREATE INDEX numindex ON test.testset (binB) NUMERIC|STRING
#
# ###### Index 'model_type'
# create index i_model_type on dev.vehicle_recall (model_type) string
#
# ###### Index 'from'
# create index i_from on dev.vehicle_recall (from) numeric
#
# ###### Index 'to'
# create index i_to on dev.vehicle_recall (to) numeric
